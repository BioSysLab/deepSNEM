# %%
from __future__ import division, print_function
from comet_ml import Experiment
import numpy as np
from numpy import inf, ndarray
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import os
import random
import keras
import sklearn
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn import metrics
import re
from keras import optimizers
from keras import losses
from keras import regularizers
import keras.backend as K
from keras.models import model_from_json
from keras.models import load_model, Model
from tempfile import TemporaryFile
from keras import layers
from rdkit import Chem
from rdkit.Chem import Draw, Descriptors
from matplotlib import pyplot as plt
# matplotlib inline
from keras.callbacks import History, ReduceLROnPlateau
from keras.layers import Input, BatchNormalization, Activation
from keras.layers import CuDNNLSTM, Dense, Bidirectional, Dropout, Layer
from keras.initializers import glorot_normal
from keras.regularizers import l2
from functools import partial
from multiprocessing import cpu_count, Pool
from keras.utils.generic_utils import Progbar
from copy import deepcopy
from NGF.utils import filter_func_args, mol_shapes_to_dims
import NGF.utils
import NGF_layers.features
import NGF_layers.graph_layers
from NGF_layers.features import one_of_k_encoding, one_of_k_encoding_unk, atom_features, bond_features, num_atom_features, num_bond_features
from NGF_layers.features import padaxis, tensorise_smiles, concat_mol_tensors
from NGF_layers.graph_layers import temporal_padding, neighbour_lookup, NeuralGraphHidden, NeuralGraphOutput
from math import ceil
from sklearn.metrics import precision_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
import networkx as nx
#from networkx.drawing.nx_agraph import graphviz_layout
from argparse import Namespace
import ast
import pickle
from scipy.sparse import coo_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, MaxAbsScaler
from scipy.spatial.distance import  cosine, pdist

#from tqdm.auto import tqdm
import sys
import seaborn as sns
sns.set()
# Out:
# Using TensorFlow backend.

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config = config)

# Check available GPU devices.
print("The following GPU devices are available: %s" % tf.test.gpu_device_name())
# Out:
# The following GPU devices are available: /device:GPU:0

# %% [markdown]
# # UGRAPHEMP Implementation using GED

# %%
samples_all=pd.read_csv("data/graph_additional/samples_all.csv",index_col=0).reset_index(drop=True)

# %%
prot_go_enc=pd.read_csv("data/prot_embeddings/new_features/bp_features.csv")
shapes_dict = {
    'num_prot_features' : 399,
    'num_edge_features' : 1
}
prot_dict={}
for i in range(len(prot_go_enc)):
    prot_dict.update({list(prot_go_enc.iloc[i])[0]:np.array(list(prot_go_enc.iloc[i])[1:len(list(prot_go_enc.iloc[i]))])})
prot_dict['Perturbation'] = np.zeros((398,))

# %%
def df_to_nx(df):
    flag=False
    net=nx.DiGraph()
    nodes=list(set(list(df['node1']) + list(df['node2'])))
    if "Perturbation" not in nodes:
        nodes.append("Perturbation")
        flag=True
    for i in range(len(nodes)):
        if ((nodes[i]=="Perturbation") and flag):
            net.add_node(nodes[i],act=0)
        elif nodes[i] in list(df['node1']):
            j=list(df['node1']).index(nodes[i])
            a=int(list(df['activity1'])[j])
            net.add_node(nodes[i],act=a)
        else:
            j=list(df['node2']).index(nodes[i])
            a=int(list(df['activity2'])[j])
            net.add_node(nodes[i],act=a)
    for i in range(len(df)):
        net.add_edge(df['node1'][i], df['node2'][i], weight=df['sign'][i])
    
    return(net)

# %%
def FastGEDEstimate(G1, G2):
    import networkx as nx
    #from networkx.drawing.nx_agraph import graphviz_layout
    import numpy as np
    from numpy import inf, ndarray
    import pandas as pd
    ged=0
    G_new=G1
    G_source=G2
    if len(list(G1.nodes()))>len(list(G2.nodes())):
        G_new=G2
        G_source=G1
    node_list_new=list(G_new.nodes())
    node_list_source=list(G_source.nodes())
    tomod=[elem for elem in node_list_source if (elem not in node_list_new)]
    toadd=[elem  for elem in node_list_new if (elem not in node_list_source)]
    #if (len(tomod)>=len(toadd)):
    ind=list(np.random.choice(len(tomod), len(toadd)))
    ged=len(tomod)+ged
    ordered_new=[x[1] for x in list(nx.bfs_tree(G_new, 'Perturbation').edges())]
    for i in list(nx.bfs_tree(G_source, 'Perturbation').edges()):
        if (i[1] in tomod):
            add=[x for x in ordered_new if x in toadd]
            if add!=[]:
                toadd.remove(add[0])
                tomod.remove(i[1])
                mapping = {i[1]:add[0]} 
                G_source= nx.relabel_nodes(G_source, mapping)
                G_source.nodes(data=True)[add[0]]['act']=G_new.nodes(data=True)[add[0]]['act']
        if toadd==[]:
            break
    for i in tomod:
        G_source.remove_node(i)
    rem1=[]
    rem2=[]
    for n1,n2,attr in G_source.edges(data=True):
        if (not G_new.has_edge(n1,n2)):
            #if G_source[n1][n2]['weight']==G_new[n1][n2]['weight']:
            ged=ged+1
            rem1.append(n1)
            rem2.append(n2)
    for i in range(len(rem1)):
        G_source.remove_edge(rem1[i], rem2[i])
    add1=[]
    add2=[]
    for n1,n2,attr in G_new.edges(data=True):
        if (not G_source.has_edge(n1,n2)):
            #if G_source[n1][n2]['weight']==G_new[n1][n2]['weight']:
            ged=ged+1
            add1.append(n1)
            add2.append(n2)
    for i in range(len(add1)):
        G_source.add_edge(add1[i], add2[i],weight=G_new[add1[i]][add2[i]]['weight'])
    for n1,n2,attr in G_source.edges(data=True):
        if ((G_source.nodes(data=True)[n1]!={}) and G_new.nodes(data=True)[n1]!={}):
            if (abs((G_source.nodes(data=True)[n1]['act']-G_new.nodes(data=True)[n1]['act'])/G_new.nodes(data=True)[n1]['act'])*100>20):
                ged=ged+1
                G_source.nodes(data=True)[n1]['act']=G_new.nodes(data=True)[n1]['act']
        if ((G_source.nodes(data=True)[n2]!={}) and G_new.nodes(data=True)[n2]!={}):
            if (abs((G_source.nodes(data=True)[n2]['act']-G_new.nodes(data=True)[n2]['act'])/G_new.nodes(data=True)[n2]['act'])*100>20):
                ged=ged+1
                G_source.nodes(data=True)[n2]['act']=G_new.nodes(data=True)[n2]['act']
        if (abs((G_source[n1][n2]['weight']-G_new[n1][n2]['weight'])/G_new[n1][n2]['weight'])*100>20):
            ged=ged+1
            G_source[n1][n2]['weight']=G_new[n1][n2]['weight']

    #return([G_source,ged])
    return(ged)

# %%
def GEDgenerator(bs,df_pairs,graphs_location,init_count):
    import numpy as np
    #counter=int(0)
    counter=int(init_count)
    #Keep looping indefinetely
    while counter<len(df_pairs):
        ged=[]
        while len(ged)<bs:
            # check to see if you reached the end of the frame
            if counter==len(df_pairs):
                break
            
            p1=graphs_location+df_pairs['graph.x'][counter]
            p2=graphs_location+df_pairs['graph.y'][counter]
            graph_df1=pd.read_csv(p1,index_col=0).reset_index(drop=True)
            graph_df2=pd.read_csv(p2,index_col=0).reset_index(drop=True)
            ged.append(FastGEDEstimate(df_to_nx(graph_df1),df_to_nx(graph_df2)))
            counter=counter+1
    
        
        yield(ged)

# %% [markdown]
# # Tensorize smiles and load data

# %%
def tensorize_signalnet(netx_list,prot_dict,max_prots,max_degree,shapes_dict):
    import numpy as np
    n = len(netx_list)
    X_prots= np.zeros((n,max_prots,shapes_dict['num_prot_features']),dtype='float32')
    Χ_edgattr=np.zeros((n,max_prots,max_degree,shapes_dict['num_edge_features']),dtype='float32')
    X_edges=np.ones((n,max_prots,max_degree),dtype='int32')*int(-1)
    for idx,netx in enumerate(netx_list):
        #print(idx)
        for i,p in enumerate(list(netx.nodes())):
            l=list(prot_dict[p])
            l.append(netx.nodes[p]['act'])
            X_prots[idx][i]=np.array(l)
            inds=[list(netx.nodes()).index(x) for x in list(netx[p])[0:max_degree]]
            attrs=[netx[p][x]['weight'] for x in list(netx[p])[0:max_degree]]
            if len(inds)<max_degree:
                for j in range(max_degree-len(inds)):
                    inds.append(-1)
                    attrs.append(0)
            X_edges[idx][i]=np.array(inds)
            Χ_edgattr[idx][i]=np.array(attrs).reshape(21,1)
    
    return X_prots,Χ_edgattr,X_edges

# %%
df_pairs=pd.read_csv("data/graph_additional/pairs/splits/split2/allpairs2.csv",index_col=0,engine = "python").reset_index(drop=True)

# %%
df_pairs.value=df_pairs.value/max(df_pairs.value)

# %%
plt.hist(df_pairs.value)
# Out:
# (array([8.890900e+04, 4.787500e+04, 1.609500e+04, 1.291890e+05,
#         7.345840e+05, 1.029933e+06, 2.102568e+06, 1.366248e+06,
#         1.572990e+05, 1.919000e+03]),
#  array([0.00421941, 0.10379747, 0.20337553, 0.30295359, 0.40253165,
#         0.5021097 , 0.60168776, 0.70126582, 0.80084388, 0.90042194,
#         1.        ]),
#  <a list of 10 Patch objects>)

# %%
nets_paths=list(set(list(df_pairs['graph.x'])+list(df_pairs['graph.y'])))
graph_df=[pd.read_csv(x,index_col=0).reset_index(drop=True) for x in nets_paths]
nets=[df_to_nx(x) for x in graph_df]

# %%
graphs_nx=tensorize_signalnet(nets,prot_dict,100,21,shapes_dict)
#graphs_nx=tensorize_signalnet([df_to_nx(y) for y in [pd.read_csv(graphs_location+x,index_col=0).reset_index(drop=True) for x in nets_paths]],prot_dict,100,21,shapes_dict)

# %%
df_labels = df_pairs[df_pairs['label1']==1].reset_index(drop=True)

# %%
df_labels
# Out:
#                                                   graph.x  \
# 0       graphs_combined/AML001_HL60_24H_BRD-A45664787_...
# 1       graphs_combined/AML001_HL60_24H_BRD-A45664787_...
# 2       graphs_combined/AML001_HL60_24H_BRD-A45664787_...
# 3       graphs_combined/AML001_HL60_24H_BRD-A45664787_...
# 4       graphs_combined/BRAF001_A375_24H_BRD-K09951645...
# 5       graphs_combined/BRAF001_A375_24H_BRD-K09951645...
# 6       graphs_combined/BRAF001_HEK293T_24H_BRD-K09951...
# 7       graphs_combined/BRAF001_HEK293T_24H_BRD-K09951...
# 8       graphs_combined/BRAF001_A375_24H_BRD-K09951645...
# 9       graphs_combined/BRAF001_A375_24H_BRD-K09951645...
# 10      graphs_combined/BRAF001_HEK293T_24H_BRD-K09951...
# 11      graphs_combined/BRAF001_HEK293T_24H_BRD-K09951...
# 12      graphs_combined/CPC001_HA1E_24H_BRD-K74305673-...
# 13      graphs_combined/CPC001_HA1E_24H_BRD-K74305673-...
# 14      graphs_combined/CPC001_HA1E_24H_BRD-K74305673-...
# 15      graphs_combined/CPC001_HA1E_24H_BRD-K74305673-...
# 16      graphs_combined/CPC001_HA1E_6H_BRD-K14618467-0...
# 17      graphs_combined/CPC001_HA1E_6H_BRD-K14618467-0...
# 18      graphs_combined/CPC001_HA1E_6H_BRD-K14618467-0...
# 19      graphs_combined/CPC001_HA1E_6H_BRD-K14618467-0...
# 20      graphs_combined/CPC001_HA1E_24H_BRD-K74305673-...
# 21      graphs_combined/CPC001_HA1E_24H_BRD-K74305673-...
# 22      graphs_combined/CPC001_HCC515_24H_BRD-K7430567...
# 23      graphs_combined/CPC001_HCC515_24H_BRD-K7430567...
# 24      graphs_combined/CPC001_HA1E_24H_BRD-K74305673-...
# 25      graphs_combined/CPC001_HA1E_24H_BRD-K74305673-...
# 26      graphs_combined/CPC001_HCC515_24H_BRD-K7430567...
# 27      graphs_combined/CPC001_HCC515_24H_BRD-K7430567...
# 28      graphs_combined/CPC001_HA1E_6H_BRD-K14618467-0...
# 29      graphs_combined/CPC001_HA1E_6H_BRD-K14618467-0...
# ...                                                   ...
# 193119  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193120  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193121  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193122  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193123  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193124  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193125  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193126  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193127  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193128  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193129  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193130  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193131  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193132  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193133  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193134  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193135  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193136  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193137  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193138  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193139  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193140  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193141  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193142  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193143  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193144  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193145  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193146  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193147  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
# 193148  graphs_combined/CPC015_SKB_24H_BRD-A68930007-0...
#
#                                                   graph.y     value  \
# 0       graphs_combined/AML001_HL60_6H_BRD-K19706299_1...  0.531646
# 1       graphs_combined/AML001_HL60_6H_BRD-K19706299_1...  0.544304
# 2       graphs_combined/AML001_HL60_6H_BRD-K19706299_1...  0.421941
# 3       graphs_combined/AML001_HL60_6H_BRD-K19706299_1...  0.430380
# 4       graphs_combined/BRAF001_HEK293T_24H_BRD-K23984...  0.485232
# 5       graphs_combined/BRAF001_HEK293T_24H_BRD-K23984...  0.738397
# 6       graphs_combined/BRAF001_HEK293T_24H_BRD-K23984...  0.257384
# 7       graphs_combined/BRAF001_HEK293T_24H_BRD-K23984...  0.396624
# 8       graphs_combined/BRAF001_HEK293T_24H_BRD-K23984...  0.481013
# 9       graphs_combined/BRAF001_HEK293T_24H_BRD-K23984...  0.704641
# 10      graphs_combined/BRAF001_HEK293T_24H_BRD-K23984...  0.253165
# 11      graphs_combined/BRAF001_HEK293T_24H_BRD-K23984...  0.371308
# 12      graphs_combined/CPC001_HA1E_6H_BRD-K14618467-0...  0.535865
# 13      graphs_combined/CPC001_HA1E_6H_BRD-K14618467-0...  0.535865
# 14      graphs_combined/CPC001_HA1E_6H_BRD-K14618467-0...  0.780591
# 15      graphs_combined/CPC001_HA1E_6H_BRD-K14618467-0...  0.780591
# 16      graphs_combined/CPC001_HCC515_24H_BRD-K7430567...  0.392405
# 17      graphs_combined/CPC001_HCC515_24H_BRD-K7430567...  0.413502
# 18      graphs_combined/CPC001_HCC515_24H_BRD-K7430567...  0.556962
# 19      graphs_combined/CPC001_HCC515_24H_BRD-K7430567...  0.864979
# 20      graphs_combined/CPC001_PC3_6H_BRD-K14618467-00...  0.628692
# 21      graphs_combined/CPC001_PC3_6H_BRD-K14618467-00...  0.594937
# 22      graphs_combined/CPC001_PC3_6H_BRD-K14618467-00...  0.248945
# 23      graphs_combined/CPC001_PC3_6H_BRD-K14618467-00...  0.548523
# 24      graphs_combined/CPC001_PC3_6H_BRD-K14618467-00...  0.641350
# 25      graphs_combined/CPC001_PC3_6H_BRD-K14618467-00...  0.603376
# 26      graphs_combined/CPC001_PC3_6H_BRD-K14618467-00...  0.244726
# 27      graphs_combined/CPC001_PC3_6H_BRD-K14618467-00...  0.544304
# 28      graphs_combined/CPC001_VCAP_24H_BRD-K74305673-...  0.468354
# 29      graphs_combined/CPC001_VCAP_24H_BRD-K74305673-...  0.683544
# ...                                                   ...       ...
# 193119  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.637131
# 193120  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.620253
# 193121  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.607595
# 193122  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.632911
# 193123  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.632911
# 193124  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.641350
# 193125  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.632911
# 193126  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.620253
# 193127  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.624473
# 193128  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.637131
# 193129  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.641350
# 193130  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.620253
# 193131  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.624473
# 193132  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.641350
# 193133  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.641350
# 193134  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.641350
# 193135  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.628692
# 193136  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.620253
# 193137  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.641350
# 193138  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.658228
# 193139  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.628692
# 193140  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.628692
# 193141  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.628692
# 193142  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.607595
# 193143  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.607595
# 193144  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.624473
# 193145  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.620253
# 193146  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.628692
# 193147  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.632911
# 193148  graphs_combined/CPC018_SKB_24H_BRD-A46747628-0...  0.611814
#
#                                                 sig_id.x       pert_iname.x  \
# 0                       AML001_HL60_24H_BRD-A45664787_10           iloprost
# 1                       AML001_HL60_24H_BRD-A45664787_10           iloprost
# 2                       AML001_HL60_24H_BRD-A45664787_10           iloprost
# 3                       AML001_HL60_24H_BRD-A45664787_10           iloprost
# 4             BRAF001_A375_24H_BRD-K09951645-001-02-7_10         dabrafenib
# 5             BRAF001_A375_24H_BRD-K09951645-001-02-7_10         dabrafenib
# 6       BRAF001_HEK293T_24H_BRD-K09951645-001-02-7_0.625         dabrafenib
# 7       BRAF001_HEK293T_24H_BRD-K09951645-001-02-7_0.625         dabrafenib
# 8             BRAF001_A375_24H_BRD-K09951645-001-02-7_10         dabrafenib
# 9             BRAF001_A375_24H_BRD-K09951645-001-02-7_10         dabrafenib
# 10      BRAF001_HEK293T_24H_BRD-K09951645-001-02-7_0.625         dabrafenib
# 11      BRAF001_HEK293T_24H_BRD-K09951645-001-02-7_0.625         dabrafenib
# 12             CPC001_HA1E_24H_BRD-K74305673-001-01-3_10  IKK-2-inhibitor-V
# 13             CPC001_HA1E_24H_BRD-K74305673-001-01-3_10  IKK-2-inhibitor-V
# 14             CPC001_HA1E_24H_BRD-K74305673-001-01-3_10  IKK-2-inhibitor-V
# 15             CPC001_HA1E_24H_BRD-K74305673-001-01-3_10  IKK-2-inhibitor-V
# 16              CPC001_HA1E_6H_BRD-K14618467-003-01-8_10             IKK-16
# 17              CPC001_HA1E_6H_BRD-K14618467-003-01-8_10             IKK-16
# 18              CPC001_HA1E_6H_BRD-K14618467-003-01-8_10             IKK-16
# 19              CPC001_HA1E_6H_BRD-K14618467-003-01-8_10             IKK-16
# 20             CPC001_HA1E_24H_BRD-K74305673-001-01-3_10  IKK-2-inhibitor-V
# 21             CPC001_HA1E_24H_BRD-K74305673-001-01-3_10  IKK-2-inhibitor-V
# 22           CPC001_HCC515_24H_BRD-K74305673-001-01-3_10  IKK-2-inhibitor-V
# 23           CPC001_HCC515_24H_BRD-K74305673-001-01-3_10  IKK-2-inhibitor-V
# 24             CPC001_HA1E_24H_BRD-K74305673-001-01-3_10  IKK-2-inhibitor-V
# 25             CPC001_HA1E_24H_BRD-K74305673-001-01-3_10  IKK-2-inhibitor-V
# 26           CPC001_HCC515_24H_BRD-K74305673-001-01-3_10  IKK-2-inhibitor-V
# 27           CPC001_HCC515_24H_BRD-K74305673-001-01-3_10  IKK-2-inhibitor-V
# 28              CPC001_HA1E_6H_BRD-K14618467-003-01-8_10             IKK-16
# 29              CPC001_HA1E_6H_BRD-K14618467-003-01-8_10             IKK-16
# ...                                                  ...                ...
# 193119          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193120          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193121          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193122          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193123          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193124          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193125          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193126          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193127          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193128          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193129          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193130          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193131          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193132          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193133          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193134          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193135          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193136          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193137          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193138          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193139          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193140          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193141          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193142          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193143          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193144          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193145          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193146          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193147          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
# 193148          CPC015_SKB_24H_BRD-A68930007-001-03-1_10            ouabain
#
#             pert_id.x                                       sig_id.y  \
# 0       BRD-A45664787           AML001_HL60_6H_BRD-K19706299_1.11111
# 1       BRD-A45664787           AML001_HL60_6H_BRD-K19706299_1.11111
# 2       BRD-A45664787           AML001_HL60_6H_BRD-K19706299_1.11111
# 3       BRD-A45664787           AML001_HL60_6H_BRD-K19706299_1.11111
# 4       BRD-K09951645  BRAF001_HEK293T_24H_BRD-K23984367-001-04-2_10
# 5       BRD-K09951645  BRAF001_HEK293T_24H_BRD-K23984367-001-04-2_10
# 6       BRD-K09951645  BRAF001_HEK293T_24H_BRD-K23984367-001-04-2_10
# 7       BRD-K09951645  BRAF001_HEK293T_24H_BRD-K23984367-001-04-2_10
# 8       BRD-K09951645  BRAF001_HEK293T_24H_BRD-K23984367-001-04-2_10
# 9       BRD-K09951645  BRAF001_HEK293T_24H_BRD-K23984367-001-04-2_10
# 10      BRD-K09951645  BRAF001_HEK293T_24H_BRD-K23984367-001-04-2_10
# 11      BRD-K09951645  BRAF001_HEK293T_24H_BRD-K23984367-001-04-2_10
# 12      BRD-K74305673       CPC001_HA1E_6H_BRD-K14618467-003-01-8_10
# 13      BRD-K74305673       CPC001_HA1E_6H_BRD-K14618467-003-01-8_10
# 14      BRD-K74305673       CPC001_HA1E_6H_BRD-K14618467-003-01-8_10
# 15      BRD-K74305673       CPC001_HA1E_6H_BRD-K14618467-003-01-8_10
# 16      BRD-K14618467    CPC001_HCC515_24H_BRD-K74305673-001-01-3_10
# 17      BRD-K14618467    CPC001_HCC515_24H_BRD-K74305673-001-01-3_10
# 18      BRD-K14618467    CPC001_HCC515_24H_BRD-K74305673-001-01-3_10
# 19      BRD-K14618467    CPC001_HCC515_24H_BRD-K74305673-001-01-3_10
# 20      BRD-K74305673        CPC001_PC3_6H_BRD-K14618467-003-01-8_10
# 21      BRD-K74305673        CPC001_PC3_6H_BRD-K14618467-003-01-8_10
# 22      BRD-K74305673        CPC001_PC3_6H_BRD-K14618467-003-01-8_10
# 23      BRD-K74305673        CPC001_PC3_6H_BRD-K14618467-003-01-8_10
# 24      BRD-K74305673        CPC001_PC3_6H_BRD-K14618467-003-01-8_10
# 25      BRD-K74305673        CPC001_PC3_6H_BRD-K14618467-003-01-8_10
# 26      BRD-K74305673        CPC001_PC3_6H_BRD-K14618467-003-01-8_10
# 27      BRD-K74305673        CPC001_PC3_6H_BRD-K14618467-003-01-8_10
# 28      BRD-K14618467      CPC001_VCAP_24H_BRD-K74305673-001-01-3_10
# 29      BRD-K14618467      CPC001_VCAP_24H_BRD-K74305673-001-01-3_10
# ...               ...                                            ...
# 193119  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193120  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193121  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193122  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193123  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193124  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193125  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193126  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193127  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193128  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193129  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193130  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193131  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193132  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193133  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193134  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193135  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193136  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193137  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193138  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193139  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193140  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193141  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193142  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193143  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193144  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193145  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193146  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193147  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
# 193148  BRD-A68930007       CPC018_SKB_24H_BRD-A46747628-001-01-9_10
#
#              pert_iname.y      pert_id.y      identifier.x      identifier.y  \
# 0                 MRE-269  BRD-K19706299               NaN               NaN
# 1                 MRE-269  BRD-K19706299               NaN               NaN
# 2                 MRE-269  BRD-K19706299               NaN               NaN
# 3                 MRE-269  BRD-K19706299               NaN               NaN
# 4               sorafenib  BRD-K23984367               NaN               NaN
# 5               sorafenib  BRD-K23984367               NaN               NaN
# 6               sorafenib  BRD-K23984367               NaN               NaN
# 7               sorafenib  BRD-K23984367               NaN               NaN
# 8               sorafenib  BRD-K23984367               NaN               NaN
# 9               sorafenib  BRD-K23984367               NaN               NaN
# 10              sorafenib  BRD-K23984367               NaN               NaN
# 11              sorafenib  BRD-K23984367               NaN               NaN
# 12                 IKK-16  BRD-K14618467               NaN               NaN
# 13                 IKK-16  BRD-K14618467               NaN               NaN
# 14                 IKK-16  BRD-K14618467               NaN               NaN
# 15                 IKK-16  BRD-K14618467               NaN               NaN
# 16      IKK-2-inhibitor-V  BRD-K74305673               NaN               NaN
# 17      IKK-2-inhibitor-V  BRD-K74305673               NaN               NaN
# 18      IKK-2-inhibitor-V  BRD-K74305673               NaN               NaN
# 19      IKK-2-inhibitor-V  BRD-K74305673               NaN               NaN
# 20                 IKK-16  BRD-K14618467               NaN               NaN
# 21                 IKK-16  BRD-K14618467               NaN               NaN
# 22                 IKK-16  BRD-K14618467               NaN               NaN
# 23                 IKK-16  BRD-K14618467               NaN               NaN
# 24                 IKK-16  BRD-K14618467               NaN               NaN
# 25                 IKK-16  BRD-K14618467               NaN               NaN
# 26                 IKK-16  BRD-K14618467               NaN               NaN
# 27                 IKK-16  BRD-K14618467               NaN               NaN
# 28      IKK-2-inhibitor-V  BRD-K74305673               NaN               NaN
# 29      IKK-2-inhibitor-V  BRD-K74305673               NaN               NaN
# ...                   ...            ...               ...               ...
# 193119            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193120            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193121            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193122            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193123            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193124            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193125            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193126            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193127            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193128            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193129            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193130            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193131            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193132            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193133            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193134            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193135            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193136            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193137            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193138            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193139            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193140            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193141            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193142            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193143            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193144            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193145            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193146            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193147            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
# 193148            ouabain  BRD-A46747628  ouabainSKB10.024  ouabainSKB10.024
#
#                                                   rdkit.x  \
# 0       CC#CCC(C)[C@H](O)/C=C/[C@@H]1[C@H]2C/C(=C/CCCC...
# 1       CC#CCC(C)[C@H](O)/C=C/[C@@H]1[C@H]2C/C(=C/CCCC...
# 2       CC#CCC(C)[C@H](O)/C=C/[C@@H]1[C@H]2C/C(=C/CCCC...
# 3       CC#CCC(C)[C@H](O)/C=C/[C@@H]1[C@H]2C/C(=C/CCCC...
# 4       CC(C)(C)c1nc(-c2cccc(NS(=O)(=O)c3c(F)cccc3F)c2...
# 5       CC(C)(C)c1nc(-c2cccc(NS(=O)(=O)c3c(F)cccc3F)c2...
# 6       CC(C)(C)c1nc(-c2cccc(NS(=O)(=O)c3c(F)cccc3F)c2...
# 7       CC(C)(C)c1nc(-c2cccc(NS(=O)(=O)c3c(F)cccc3F)c2...
# 8       CC(C)(C)c1nc(-c2cccc(NS(=O)(=O)c3c(F)cccc3F)c2...
# 9       CC(C)(C)c1nc(-c2cccc(NS(=O)(=O)c3c(F)cccc3F)c2...
# 10      CC(C)(C)c1nc(-c2cccc(NS(=O)(=O)c3c(F)cccc3F)c2...
# 11      CC(C)(C)c1nc(-c2cccc(NS(=O)(=O)c3c(F)cccc3F)c2...
# 12        O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)c1cc(Cl)ccc1O
# 13        O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)c1cc(Cl)ccc1O
# 14        O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)c1cc(Cl)ccc1O
# 15        O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)c1cc(Cl)ccc1O
# 16      O=C(c1ccc(Nc2nccc(-c3cc4ccccc4s3)n2)cc1)N1CCC(...
# 17      O=C(c1ccc(Nc2nccc(-c3cc4ccccc4s3)n2)cc1)N1CCC(...
# 18      O=C(c1ccc(Nc2nccc(-c3cc4ccccc4s3)n2)cc1)N1CCC(...
# 19      O=C(c1ccc(Nc2nccc(-c3cc4ccccc4s3)n2)cc1)N1CCC(...
# 20        O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)c1cc(Cl)ccc1O
# 21        O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)c1cc(Cl)ccc1O
# 22        O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)c1cc(Cl)ccc1O
# 23        O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)c1cc(Cl)ccc1O
# 24        O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)c1cc(Cl)ccc1O
# 25        O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)c1cc(Cl)ccc1O
# 26        O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)c1cc(Cl)ccc1O
# 27        O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)c1cc(Cl)ccc1O
# 28      O=C(c1ccc(Nc2nccc(-c3cc4ccccc4s3)n2)cc1)N1CCC(...
# 29      O=C(c1ccc(Nc2nccc(-c3cc4ccccc4s3)n2)cc1)N1CCC(...
# ...                                                   ...
# 193119                                                NaN
# 193120                                                NaN
# 193121                                                NaN
# 193122                                                NaN
# 193123                                                NaN
# 193124                                                NaN
# 193125                                                NaN
# 193126                                                NaN
# 193127                                                NaN
# 193128                                                NaN
# 193129                                                NaN
# 193130                                                NaN
# 193131                                                NaN
# 193132                                                NaN
# 193133                                                NaN
# 193134                                                NaN
# 193135                                                NaN
# 193136                                                NaN
# 193137                                                NaN
# 193138                                                NaN
# 193139                                                NaN
# 193140                                                NaN
# 193141                                                NaN
# 193142                                                NaN
# 193143                                                NaN
# 193144                                                NaN
# 193145                                                NaN
# 193146                                                NaN
# 193147                                                NaN
# 193148                                                NaN
#
#                                                   rdkit.y            moa_v1.x  \
# 0       CCCCC[C@H](O)CC[C@@H]1[C@H]2Cc3cccc(OCC(=O)O)c...  prostanoid_agonist
# 1       CCCCC[C@H](O)CC[C@@H]1[C@H]2Cc3cccc(OCC(=O)O)c...  prostanoid_agonist
# 2       CCCCC[C@H](O)CC[C@@H]1[C@H]2Cc3cccc(OCC(=O)O)c...  prostanoid_agonist
# 3       CCCCC[C@H](O)CC[C@@H]1[C@H]2Cc3cccc(OCC(=O)O)c...  prostanoid_agonist
# 4       CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)...       raf_inhibitor
# 5       CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)...       raf_inhibitor
# 6       CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)...       raf_inhibitor
# 7       CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)...       raf_inhibitor
# 8       CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)...       raf_inhibitor
# 9       CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)...       raf_inhibitor
# 10      CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)...       raf_inhibitor
# 11      CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)...       raf_inhibitor
# 12      O=C(c1ccc(Nc2nccc(-c3cc4ccccc4s3)n2)cc1)N1CCC(...       ikk_inhibitor
# 13      O=C(c1ccc(Nc2nccc(-c3cc4ccccc4s3)n2)cc1)N1CCC(...       ikk_inhibitor
# 14      O=C(c1ccc(Nc2nccc(-c3cc4ccccc4s3)n2)cc1)N1CCC(...       ikk_inhibitor
# 15      O=C(c1ccc(Nc2nccc(-c3cc4ccccc4s3)n2)cc1)N1CCC(...       ikk_inhibitor
# 16        O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)c1cc(Cl)ccc1O       ikk_inhibitor
# 17        O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)c1cc(Cl)ccc1O       ikk_inhibitor
# 18        O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)c1cc(Cl)ccc1O       ikk_inhibitor
# 19        O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)c1cc(Cl)ccc1O       ikk_inhibitor
# 20      O=C(c1ccc(Nc2nccc(-c3cc4ccccc4s3)n2)cc1)N1CCC(...       ikk_inhibitor
# 21      O=C(c1ccc(Nc2nccc(-c3cc4ccccc4s3)n2)cc1)N1CCC(...       ikk_inhibitor
# 22      O=C(c1ccc(Nc2nccc(-c3cc4ccccc4s3)n2)cc1)N1CCC(...       ikk_inhibitor
# 23      O=C(c1ccc(Nc2nccc(-c3cc4ccccc4s3)n2)cc1)N1CCC(...       ikk_inhibitor
# 24      O=C(c1ccc(Nc2nccc(-c3cc4ccccc4s3)n2)cc1)N1CCC(...       ikk_inhibitor
# 25      O=C(c1ccc(Nc2nccc(-c3cc4ccccc4s3)n2)cc1)N1CCC(...       ikk_inhibitor
# 26      O=C(c1ccc(Nc2nccc(-c3cc4ccccc4s3)n2)cc1)N1CCC(...       ikk_inhibitor
# 27      O=C(c1ccc(Nc2nccc(-c3cc4ccccc4s3)n2)cc1)N1CCC(...       ikk_inhibitor
# 28        O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)c1cc(Cl)ccc1O       ikk_inhibitor
# 29        O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)c1cc(Cl)ccc1O       ikk_inhibitor
# ...                                                   ...                 ...
# 193119                                                NaN                 NaN
# 193120                                                NaN                 NaN
# 193121                                                NaN                 NaN
# 193122                                                NaN                 NaN
# 193123                                                NaN                 NaN
# 193124                                                NaN                 NaN
# 193125                                                NaN                 NaN
# 193126                                                NaN                 NaN
# 193127                                                NaN                 NaN
# 193128                                                NaN                 NaN
# 193129                                                NaN                 NaN
# 193130                                                NaN                 NaN
# 193131                                                NaN                 NaN
# 193132                                                NaN                 NaN
# 193133                                                NaN                 NaN
# 193134                                                NaN                 NaN
# 193135                                                NaN                 NaN
# 193136                                                NaN                 NaN
# 193137                                                NaN                 NaN
# 193138                                                NaN                 NaN
# 193139                                                NaN                 NaN
# 193140                                                NaN                 NaN
# 193141                                                NaN                 NaN
# 193142                                                NaN                 NaN
# 193143                                                NaN                 NaN
# 193144                                                NaN                 NaN
# 193145                                                NaN                 NaN
# 193146                                                NaN                 NaN
# 193147                                                NaN                 NaN
# 193148                                                NaN                 NaN
#
#                   moa_v1.y  label  label1  label2  label3  label4
# 0       prostanoid_agonist      1       1       1       1       1
# 1       prostanoid_agonist      1       1       1       1       1
# 2       prostanoid_agonist      1       1       1       1       1
# 3       prostanoid_agonist      1       1       1       1       1
# 4            raf_inhibitor      1       1       1       1       1
# 5            raf_inhibitor      1       1       1       1       1
# 6            raf_inhibitor      1       1       1       1       1
# 7            raf_inhibitor      1       1       1       1       1
# 8            raf_inhibitor      1       1       1       1       1
# 9            raf_inhibitor      1       1       1       1       1
# 10           raf_inhibitor      1       1       1       1       1
# 11           raf_inhibitor      1       1       1       1       1
# 12           ikk_inhibitor      1       1       1       1       1
# 13           ikk_inhibitor      1       1       1       1       1
# 14           ikk_inhibitor      1       1       1       1       1
# 15           ikk_inhibitor      1       1       1       1       1
# 16           ikk_inhibitor      1       1       1       1       1
# 17           ikk_inhibitor      1       1       1       1       1
# 18           ikk_inhibitor      1       1       1       1       1
# 19           ikk_inhibitor      1       1       1       1       1
# 20           ikk_inhibitor      1       1       1       1       1
# 21           ikk_inhibitor      1       1       1       1       1
# 22           ikk_inhibitor      1       1       1       1       1
# 23           ikk_inhibitor      1       1       1       1       1
# 24           ikk_inhibitor      1       1       1       1       1
# 25           ikk_inhibitor      1       1       1       1       1
# 26           ikk_inhibitor      1       1       1       1       1
# 27           ikk_inhibitor      1       1       1       1       1
# 28           ikk_inhibitor      1       1       1       1       1
# 29           ikk_inhibitor      1       1       1       1       1
# ...                    ...    ...     ...     ...     ...     ...
# 193119                 NaN      1       1       1       1       1
# 193120                 NaN      1       1       1       1       1
# 193121                 NaN      1       1       1       1       1
# 193122                 NaN      1       1       1       1       1
# 193123                 NaN      1       1       1       1       1
# 193124                 NaN      1       1       1       1       1
# 193125                 NaN      1       1       1       1       1
# 193126                 NaN      1       1       1       1       1
# 193127                 NaN      1       1       1       1       1
# 193128                 NaN      1       1       1       1       1
# 193129                 NaN      1       1       1       1       1
# 193130                 NaN      1       1       1       1       1
# 193131                 NaN      1       1       1       1       1
# 193132                 NaN      1       1       1       1       1
# 193133                 NaN      1       1       1       1       1
# 193134                 NaN      1       1       1       1       1
# 193135                 NaN      1       1       1       1       1
# 193136                 NaN      1       1       1       1       1
# 193137                 NaN      1       1       1       1       1
# 193138                 NaN      1       1       1       1       1
# 193139                 NaN      1       1       1       1       1
# 193140                 NaN      1       1       1       1       1
# 193141                 NaN      1       1       1       1       1
# 193142                 NaN      1       1       1       1       1
# 193143                 NaN      1       1       1       1       1
# 193144                 NaN      1       1       1       1       1
# 193145                 NaN      1       1       1       1       1
# 193146                 NaN      1       1       1       1       1
# 193147                 NaN      1       1       1       1       1
# 193148                 NaN      1       1       1       1       1
#
# [193149 rows x 20 columns]

# %% [markdown]
# # Generators

# %%
def train_generator(bs,df,df_labels,nets_paths,graphs_nx,shapes_dict,prot_dict,max_prots,max_degree):
    import numpy as np
    counter=int(0)
    #Keep looping indefinetely
    while True:
        
        #Initialize batches of inputs and outputs
        ind1 = []
        ind2 = []
        
        d=[]
        label = []
        #Keep looping until we reach batch size
        while len(ind1)<=bs: #doesn't matter if it is smi1 or smi2 since they have the same len
            
            # check to see if you reached the end of the frame
            if counter==len(df):
                counter=int(0)
                df = df.sample(frac=1).reset_index(drop=True)
            
            p1=df['graph.x'][counter]
            p2=df['graph.y'][counter]
            ind1.append(nets_paths.index(p1))
            ind2.append(nets_paths.index(p2))
            d.append(1-df.value[counter])
            label.append(df.label1[counter])
            counter+=1
        
        for k in range(50):
            df_sampled = df_labels.sample(1).reset_index(drop=True)
            p1_extra=df_sampled['graph.x'][0]
            p2_extra=df_sampled['graph.y'][0]
            ind1.append(nets_paths.index(p1_extra))
            ind2.append(nets_paths.index(p2_extra))
            d.append(1-df_sampled.value[0])
            label.append(df_sampled.label1[0])
        #l=[tensorize_signalnet(net,prot_dict,max_prots,max_degree,shapes_dict) for net in net1]
        #X_prots= np.array([x[0] for x in l])
        #X_edgeattr= np.array([x[1] for x in l])
        #X_edges=np.array([x[2] for x in l])
        #prot_1,edgattr_1,edge_1=tensorize_signalnet(net1,prot_dict,max_prots,max_degree,shapes_dict)
        prot_1=np.array(graphs_nx[0][ind1],dtype = 'float32')
        edgattr_1=np.array(graphs_nx[1][ind1],dtype = 'float32')
        edge_1=np.array(graphs_nx[2][ind1],dtype = 'int32')
        #l=[tensorize_signalnet(net,prot_dict,max_prots,max_degree,shapes_dict) for net in net2]
        #X_prots= np.array([x[0] for x in l])
        #X_edgeattr= np.array([x[1] for x in l])
        #X_edges=np.array([x[2] for x in l])
        #prot_2,edgattr_2,edge_2=tensorize_signalnet(net2,prot_dict,max_prots,max_degree,shapes_dict)
        prot_2=np.array(graphs_nx[0][ind2],dtype = 'float32')
        edgattr_2=np.array(graphs_nx[1][ind2],dtype = 'float32')
        edge_2=np.array(graphs_nx[2][ind2],dtype = 'int32')
        
        # yield the batch to the calling function
        yield ({'prot_inputs_1':prot_1,'edgattr_inputs_1':edgattr_1,'edge_inputs_1':edge_1,'prot_inputs_2':prot_2,
                'edgattr_inputs_2':edgattr_2,'edge_inputs_2':edge_2,'moa_inputs':np.array(label,dtype='float32')},np.array(d,dtype = 'float32'))

# %%
max_prots = 100
max_degree = 21
num_prot_features = shapes_dict['num_prot_features']
num_edge_features = shapes_dict['num_edge_features']

# %% [markdown]
# # Dictionary and custom metrics

# %%
def r_square(y_true, y_pred):
    from keras import backend as K
    SS_res =  K.sum(K.square(y_true - y_pred))
    SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return (1 - SS_res/(SS_tot + K.epsilon()))

def get_cindex(y_true, y_pred):
    g = tf.subtract(tf.expand_dims(y_pred, -1), y_pred)
    g = tf.cast(g == 0.0, tf.float32) * 0.5 + tf.cast(g > 0.0, tf.float32)

    f = tf.subtract(tf.expand_dims(y_true, -1), y_true) > 0.0
    f = tf.matrix_band_part(tf.cast(f, tf.float32), -1, 0)

    g = tf.reduce_sum(tf.multiply(g, f))
    f = tf.reduce_sum(f)

    return tf.where(tf.equal(g, 0), 0.0, g/f)

def pearson_r(y_true, y_pred):
    x = y_true
    y = y_pred
    mx = K.mean(x, axis=0)
    my = K.mean(y, axis=0)
    xm, ym = x - mx, y - my
    r_num = K.sum(xm * ym)
    x_square_sum = K.sum(xm * xm)
    y_square_sum = K.sum(ym * ym)
    r_den = K.sqrt(x_square_sum * y_square_sum)
    r = r_num / r_den
    return K.mean(r)

def mse_sliced(y_true,y_pred):
    condition = tf.math.less_equal(y_pred,0.2)
    indices = tf.where(condition)
    slice_true = tf.gather_nd(y_true,indices)
    slice_pred = tf.gather_nd(y_pred,indices)
    mse_sliced = K.mean(K.square(slice_pred - slice_true), axis=-1)
    return mse_sliced

def custom_accuracy(y_true,y_pred):
    cat_true = tf.math.less_equal(y_true,0.2)
    cat_pred = tf.math.less_equal(y_pred,0.2)
    casted_true = K.cast(cat_true,"int32")
    casted_pred = K.cast(cat_pred,"int32")
    acc = K.mean(K.equal(casted_true, K.round(casted_pred)))
    return acc

def precision(y_true, y_pred):
        """Precision metric.
        Computes the precision over the whole batch using threshold_value.
        """
        cat_true = tf.math.less_equal(y_true,0.2)
        casted_true = K.cast(cat_true,"float32")
        cat_pred = tf.math.less_equal(y_pred,0.2)
        casted_pred = K.cast(cat_pred,"float32")
        # Compute the number of true positives.
        true_positives = K.sum(tf.math.multiply(casted_true , casted_pred ))
        # count the predicted positives
        predicted_positives = K.sum(casted_pred)
        # Get the precision ratio
        precision_ratio = tf.math.divide(true_positives , predicted_positives + K.epsilon() )
        return precision_ratio

# %%
def custom_loss(sigma):
    def gaussian_loss(y_true, y_pred):
        return tf.reduce_mean(0.5*tf.log(sigma) + 0.5*tf.div(tf.square(y_true - y_pred), sigma)) + 1e-6
    return gaussian_loss

class GaussianLayer(Layer):
    def __init__(self, output_dim, **kwargs):
        self.output_dim = output_dim
        super(GaussianLayer, self).__init__(**kwargs)
    def build(self, input_shape):
        self.kernel_1 = self.add_weight(name='kernel_1', 
                                      shape=(int(input_shape[-1]), self.output_dim),
                                      initializer=glorot_normal(),
                                      trainable=True)
        self.kernel_2 = self.add_weight(name='kernel_2', 
                                      shape=(int(input_shape[-1]), self.output_dim),
                                      initializer=glorot_normal(),
                                      trainable=True)
        self.bias_1 = self.add_weight(name='bias_1',
                                    shape=(self.output_dim, ),
                                    initializer=glorot_normal(),
                                    trainable=True)
        self.bias_2 = self.add_weight(name='bias_2',
                                    shape=(self.output_dim, ),
                                    initializer=glorot_normal(),
                                    trainable=True)
        super(GaussianLayer, self).build(input_shape) 
    def call(self, x):
        output_mu  = K.dot(x, self.kernel_1) + self.bias_1
        output_sig = K.dot(x, self.kernel_2) + self.bias_2
        output_sig_pos = K.log(1 + K.exp(output_sig)) + 1e-06  
        return [output_mu, output_sig_pos]
    def compute_output_shape(self, input_shape):
        return [(input_shape[0], self.output_dim), (input_shape[0], self.output_dim)]

class ConGaussianLayer(Layer):
    def __init__(self, output_dim, **kwargs):
        self.output_dim = output_dim
        super(ConGaussianLayer, self).__init__(**kwargs)
    def build(self, input_shape):
        self.kernel_1 = self.add_weight(name='kernel_1', 
                                      shape=(int(input_shape[-1]), self.output_dim),
                                      initializer=glorot_normal(),
                                      trainable=True)
        self.kernel_2 = self.add_weight(name='kernel_2', 
                                      shape=(int(input_shape[-1]), self.output_dim),
                                      initializer=glorot_normal(),
                                      trainable=True)
        self.bias_1 = self.add_weight(name='bias_1',
                                    shape=(self.output_dim, ),
                                    initializer=glorot_normal(),
                                    trainable=True)
        self.bias_2 = self.add_weight(name='bias_2',
                                    shape=(self.output_dim, ),
                                    initializer=glorot_normal(),
                                    trainable=True)
        super(ConGaussianLayer, self).build(input_shape) 
    def call(self, x):
        output_mu  = K.dot(x, self.kernel_1) + self.bias_1
        output_mu  = keras.layers.ReLU(max_value=1)(output_mu)
        output_sig = K.dot(x, self.kernel_2) + self.bias_2
        output_sig_pos = K.log(1 + K.exp(output_sig)) + 1e-06 
        output_sig_pos  = keras.layers.ReLU(max_value=1)(output_sig_pos) + 1e-06 
        return [output_mu, output_sig_pos]
    def compute_output_shape(self, input_shape):
        return [(input_shape[0], self.output_dim), (input_shape[0], self.output_dim)]


def euclidean_distance(x,y):
    #x, y = vects
    #eucl=tf.sqrt(tf.math.reduce_sum(tf.square(tf.subtract(x,y),"Square"),"Sqrt"),axis=1,keepdims=True)
    sum_square = K.sum(K.square(x - y), axis=1, keepdims=True)
    return K.sqrt(K.maximum(sum_square, K.epsilon()))
    #return eucl


def eucl_dist_output_shape(shapes):
    shape1, shape2 = shapes
    return (shape1[0], 1)

class Attention_theta(Layer):
    def __init__(self, **kwargs):
        super(Attention_theta, self).__init__(**kwargs)
    def build(self, input_shape):
        self.theta = self.add_weight(name='theta', 
                                      shape=(int(input_shape[-1]), int(input_shape[-1])),
                                      initializer=glorot_normal(),
                                      trainable=True)
        super(Attention_theta, self).build(input_shape) 
    def call(self, x):
        import numpy as np
        multi1  = K.dot(tf.math.reduce_mean(x,axis=1),self.theta)
        #multi1=tf.transpose(multi1)
        #print(K.int_shape(multi1))
        multi1=Activation('relu')(multi1)
        multi2  = K.batch_dot(x,multi1,axes=(2,1))
        multi2=Activation('sigmoid')(multi2)
        #print(K.int_shape(multi2))
        #print(K.int_shape(x))
        output_emb = K.batch_dot(multi2,x,axes=1)
        output_emb=keras.layers.Reshape((1,K.int_shape(output_emb)[1]))(output_emb)
        #print(K.int_shape(output_emb))
        return output_emb
    def compute_output_shape(self, input_shape):
        return (input_shape[0],1,int(input_shape[-1]))

# %% [markdown]
# # Model

# %%
p = {'lr': 0.0001,
     'nfilters': int(32),
     'size': int(8),
     'conv_width' : 128,
     'fp_length' : 256,
     'size_drug_1' : 8,
     'size_drug_2' : 4,
     'size_protein_1' : 8,
     'size_protein_2' : 16,
     'size_protein_3' : 3,
     'batch_size': int(128),
     'dense_size': int(256),
     'dense_size_2': 512,
     'dropout': 0.25,
     'l2reg': 0.00}

# %% [markdown]
# # Evaluation function

# %%
def model_evaluate(y_pred,Y_cold,th,df_cold):
    true = np.reshape(Y_cold,len(df_cold))
    pred = np.reshape(y_pred,len(df_cold))
    cor = np.corrcoef(true,pred)
    mse_all = sklearn.metrics.mean_squared_error(true,pred)
    # calculate mse of similars
    mse_sims = sklearn.metrics.mean_squared_error(true[pred<=th],pred[pred<=th])
    # turn to categorical to calculate precision and accuracy
    true_cat = true <= th
    pred_cat = pred <= th
    pos = np.sum(pred_cat)
    prec = precision_score(true_cat,pred_cat)
    # calculate accuracy
    acc = accuracy_score(true_cat,pred_cat)
    result =pd.DataFrame({'cor' : cor[0,1], 'mse_all' : mse_all, 'mse_similars' : mse_sims,'precision': prec, 'accuracy': acc,
                         'positives' : pos}, index=[0])
    return(result)

# %%
def custom_loss_2(labels):
    def double_cosine(y_true, y_pred):
        condition = tf.math.equal(labels,1)
        indices = tf.where(condition)
        sliced_sim = tf.gather_nd(y_pred,indices)
        mean_sim = tf.reduce_mean(tf.subtract(1.0,sliced_sim))
        return 0.5*tf.reduce_mean(K.square(y_pred - y_true), axis=-1) + 0.5*mean_sim
    return double_cosine

# %%
def metric_cosine(labels):
    def cosine(y_true, y_pred):
        condition = tf.math.equal(labels,1)
        indices = tf.where(condition)
        sliced_sim = tf.gather_nd(y_pred,indices)
        mean_sim = tf.reduce_mean(tf.subtract(1.0,sliced_sim))
        return mean_sim
    return cosine

# %% [markdown]
# # Fit ensembles

# %%
def enc_nikos(params, lr_value, conv_width, fp_length):
        
    ### encode smiles
    
    prots0 = Input(name='prot_inputs', shape=(max_prots, num_prot_features),dtype = 'float32')
    edgattrs = Input(name='edgattr_inputs', shape=(max_prots, max_degree, num_edge_features),dtype = 'float32')
    edges = Input(name='edge_inputs', shape=(max_prots, max_degree), dtype='int32')

    #prosoxi arxika to kano 256 ton pinaka
    g1 = NeuralGraphHidden(128 , activ = None, bias = True , init = 'glorot_normal')([prots0,edgattrs,edges])
    g1 = BatchNormalization(momentum=0.6)(g1)
    g1 = Activation('relu')(g1)
    #g1=keras.layers.Dropout(0.4)(g1)

    g2 = NeuralGraphHidden(128  , activ = None, bias = True , init = 'glorot_normal')([g1,edgattrs,edges])
    g2 = BatchNormalization(momentum=0.6)(g2)
    g2 = Activation('relu')(g2)
    #g2=keras.layers.Dropout(0.4)(g2)

    g3 = NeuralGraphHidden(128  , activ = None, bias = True , init = 'glorot_normal')([g2,edgattrs,edges])
    g3 = BatchNormalization(momentum=0.6)(g3)
    g3 = Activation('relu')(g3)



    g4=keras.layers.Conv1D(512,37, activation=None, use_bias=False, kernel_initializer='glorot_uniform')(g3)
    g4= BatchNormalization(momentum=0.6)(g4)
    g4 = Activation('relu')(g4)
    #g4=keras.layers.Dropout(0.3)(g4)
    
    #g5=keras.layers.Conv1D(512,33, activation=None, use_bias=False, kernel_initializer='glorot_uniform')(g4)
    #g5= BatchNormalization(momentum=0.6)(g5)
    #g5 = Activation('relu')(g5)
    #g5=keras.layers.Dropout(0.3)(g5)
    
    #g6=keras.layers.Conv1D(128,32, activation=None, use_bias=False, kernel_initializer='glorot_uniform')(g5)
    #g6= BatchNormalization(momentum=0.6)(g6)
    #g6 = Activation('relu')(g6)
    #g6=keras.layers.Dropout(0.3)(g6)
    #g6=keras.layers.Flatten()(g6)
    g6=keras.layers.AveragePooling1D(pool_size=64)(g4)
    g6=keras.layers.Flatten()(g6)
    
    emb = keras.layers.Dense(512,activation = None,kernel_regularizer=None, kernel_initializer='glorot_normal')(g6)
    emb = keras.layers.Lambda(lambda x: K.l2_normalize(x,axis=1))(emb)



    interactionModel = keras.Model(inputs=[prots0, edgattrs, edges], outputs= emb)

    print(interactionModel.summary())
    return interactionModel

# %%
# Initialize encoder
encoder_nikos = enc_nikos(p, 0.001, 256, 256)

# Initialize model
prots0_1 = Input(name='prot_inputs_1', shape=(max_prots, num_prot_features),dtype = 'float32')
edgattr_1 = Input(name='edgattr_inputs_1', shape=(max_prots, max_degree, num_edge_features),dtype = 'float32')
edges_1 = Input(name='edge_inputs_1', shape=(max_prots, max_degree), dtype='int32')

prots0_2 = Input(name='prot_inputs_2', shape=(max_prots, num_prot_features),dtype = 'float32')
edgattr_2 = Input(name='edgattr_inputs_2', shape=(max_prots, max_degree, num_edge_features),dtype = 'float32')
edges_2 =Input(name='edge_inputs_2', shape=(max_prots, max_degree), dtype='int32')

label=Input(name='moa_inputs',shape=(1,),dtype='float32')

encoded_1 = encoder_nikos([prots0_1,edgattr_1,edges_1])
#encoded_1 =keras.layers.Flatten()(encoded_1)
encoded_2 = encoder_nikos([prots0_2,edgattr_2,edges_2])
#encoded_2 = keras.layers.Flatten()(encoded_2)

prediction = keras.layers.dot([encoded_1,encoded_2],axes = 1, normalize=True)

siamese_net = Model(inputs=[prots0_1,edgattr_1,edges_1,prots0_2,edgattr_2,edges_2,label],outputs=prediction)
print(siamese_net.summary())
adam = keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-8, decay=0.0, amsgrad=False)
siamese_net.compile(optimizer= adam,loss= custom_loss_2(label),metrics=['mse', get_cindex, r_square, pearson_r,metric_cosine(label)])
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# prot_inputs (InputLayer)        (None, 100, 399)     0
# __________________________________________________________________________________________________
# edgattr_inputs (InputLayer)     (None, 100, 21, 1)   0
# __________________________________________________________________________________________________
# edge_inputs (InputLayer)        (None, 100, 21)      0
# __________________________________________________________________________________________________
# neural_graph_hidden_1 (NeuralGr (None, 100, 128)     1077888     prot_inputs[0][0]
#                                                                  edgattr_inputs[0][0]
#                                                                  edge_inputs[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 100, 128)     512         neural_graph_hidden_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 100, 128)     0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# neural_graph_hidden_2 (NeuralGr (None, 100, 128)     349440      activation_1[0][0]
#                                                                  edgattr_inputs[0][0]
#                                                                  edge_inputs[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 100, 128)     512         neural_graph_hidden_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 100, 128)     0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# neural_graph_hidden_3 (NeuralGr (None, 100, 128)     349440      activation_2[0][0]
#                                                                  edgattr_inputs[0][0]
#                                                                  edge_inputs[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 100, 128)     512         neural_graph_hidden_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 100, 128)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 64, 512)      2424832     activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 512)      2048        conv1d_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 512)      0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_1 (AveragePoo (None, 1, 512)       0           activation_4[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 512)          0           average_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# dense_64 (Dense)                (None, 512)          262656      flatten_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 512)          0           dense_64[0][0]
# ==================================================================================================
# Total params: 4,467,840
# Trainable params: 4,466,048
# Non-trainable params: 1,792
# __________________________________________________________________________________________________
# None
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# prot_inputs_1 (InputLayer)      (None, 100, 399)     0
# __________________________________________________________________________________________________
# edgattr_inputs_1 (InputLayer)   (None, 100, 21, 1)   0
# __________________________________________________________________________________________________
# edge_inputs_1 (InputLayer)      (None, 100, 21)      0
# __________________________________________________________________________________________________
# prot_inputs_2 (InputLayer)      (None, 100, 399)     0
# __________________________________________________________________________________________________
# edgattr_inputs_2 (InputLayer)   (None, 100, 21, 1)   0
# __________________________________________________________________________________________________
# edge_inputs_2 (InputLayer)      (None, 100, 21)      0
# __________________________________________________________________________________________________
# model_1 (Model)                 (None, 512)          4467840     prot_inputs_1[0][0]
#                                                                  edgattr_inputs_1[0][0]
#                                                                  edge_inputs_1[0][0]
#                                                                  prot_inputs_2[0][0]
#                                                                  edgattr_inputs_2[0][0]
#                                                                  edge_inputs_2[0][0]
# __________________________________________________________________________________________________
# dot_1 (Dot)                     (None, 1)            0           model_1[1][0]
#                                                                  model_1[2][0]
# ==================================================================================================
# Total params: 4,467,840
# Trainable params: 4,466,048
# Non-trainable params: 1,792
# __________________________________________________________________________________________________
# None

# %%
rlr = ReduceLROnPlateau(monitor='loss', factor=0.5,patience=1, min_lr=0.00001, verbose=1, min_delta=1e-5)
term=keras.callbacks.TerminateOnNaN()
bs=256
NUM_EPOCHS = 1
df_pairs = df_pairs.sample(frac=1).reset_index(drop=True)
#Set total number of training samples and tests samples
NUM_TRAIN = len(df_pairs)
trainGen=train_generator(bs,df_pairs,df_labels,nets_paths,graphs_nx,shapes_dict,prot_dict,max_prots,max_degree)
history = siamese_net.fit_generator(trainGen,
                                    steps_per_epoch= ceil(NUM_TRAIN/bs),
                                    epochs=NUM_EPOCHS,
                                    verbose = 1,
                                    shuffle = True,
                                    callbacks= [term, rlr])
# Out:
# C:\Users\user\Miniconda3\lib\site-packages\tensorflow\python\ops\gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# C:\Users\user\Miniconda3\lib\site-packages\tensorflow\python\ops\gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# C:\Users\user\Miniconda3\lib\site-packages\tensorflow\python\ops\gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# C:\Users\user\Miniconda3\lib\site-packages\tensorflow\python\ops\gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/1
# 22167/22167 [==============================] - 16110s 727ms/step - loss: 0.0388 - mean_squared_error: 0.0571 - get_cindex: 0.6994 - r_square: -0.4365 - pearson_r: 0.6393 - cosine: 0.0205

# %%
rlr = ReduceLROnPlateau(monitor='loss', factor=0.5,patience=1, min_lr=0.00001, verbose=1, min_delta=1e-5)
term=keras.callbacks.TerminateOnNaN()
bs=256
NUM_EPOCHS = 4
df_pairs = df_pairs.sample(frac=1).reset_index(drop=True)
#Set total number of training samples and tests samples
NUM_TRAIN = len(df_pairs)
trainGen=train_generator(bs,df_pairs,df_labels,nets_paths,graphs_nx,shapes_dict,prot_dict,max_prots,max_degree)
history = siamese_net.fit_generator(trainGen,
                                    steps_per_epoch= ceil(NUM_TRAIN/bs),
                                    epochs=NUM_EPOCHS,
                                    verbose = 1,
                                    shuffle = True,
                                    callbacks= [term, rlr])
# Out:
# C:\Users\user\Miniconda3\lib\site-packages\tensorflow\python\ops\gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# C:\Users\user\Miniconda3\lib\site-packages\tensorflow\python\ops\gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# C:\Users\user\Miniconda3\lib\site-packages\tensorflow\python\ops\gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# C:\Users\user\Miniconda3\lib\site-packages\tensorflow\python\ops\gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/4
# 22167/22167 [==============================] - 15364s 693ms/step - loss: 0.0407 - mean_squared_error: 0.0610 - get_cindex: 0.6946 - r_square: -0.5487 - pearson_r: 0.6231 - cosine: 0.0205
# Epoch 2/4
#  8697/22167 [==========>...................] - ETA: 2:35:25 - loss: 0.0304 - mean_squared_error: 0.0548 - get_cindex: 0.7079 - r_square: -0.3936 - pearson_r: 0.6418 - cosine: 0.0059
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-f133c1b52214> in <module>
#      12                                     verbose = 1,
#      13                                     shuffle = True,
# ---> 14                                     callbacks= [term, rlr])
#
# ~\Miniconda3\lib\site-packages\comet_ml\monkey_patching.py in wrapper(*args, **kwargs)
#     241                     )
#     242
# --> 243         return_value = original(*args, **kwargs)
#     244
#     245         # Call after callbacks once we have the return value
#
# ~\Miniconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\Miniconda3\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# ~\Miniconda3\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# ~\Miniconda3\lib\site-packages\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# ~\Miniconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~\Miniconda3\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~\Miniconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
NUM_EPOCHS = 1
df_pairs = df_pairs.sample(frac=1).reset_index(drop=True)
#Set total number of training samples and tests samples
NUM_TRAIN = len(df_pairs)
trainGen=train_generator(bs,df_pairs,df_labels,nets_paths,graphs_nx,shapes_dict,prot_dict,max_prots,max_degree)
history = siamese_net.fit_generator(trainGen,
                                    steps_per_epoch= ceil(NUM_TRAIN/bs),
                                    epochs=NUM_EPOCHS,
                                    verbose = 1,
                                    shuffle = True,
                                    callbacks= [term, rlr])
# Out:
# Epoch 1/1
# 22167/22167 [==============================] - 16206s 731ms/step - loss: 0.0265 - mean_squared_error: 0.0491 - get_cindex: 0.7328 - r_square: -0.2484 - pearson_r: 0.6627 - cosine: 0.0039

# %%
siamese_net.save_weights("models/ugraphemb/ss_1ep_cosine_split2.h5")
encoder_nikos.save_weights("models/ugraphemb/ss_1ep_cosine_encoder_split2.h5")

# %%
encoder_nikos.load_weights("Ugraphemp/models/encoder_model512_2.h5")

# %%
emb=encoder_nikos.predict([graphs_nx[0],graphs_nx[1],graphs_nx[2]],batch_size=512)

# %% [markdown]
# # Train embeddings

# %%
emb_id=[]
for f in nets_paths:
    emb_id.append(f.strip(".csv").split("/")[-2] + "_emb_" + str(f.strip(".csv").split("_")[-1]))
output_embs={}
output_embs.update({'emb':emb_id})
for i in range(512):
    output_embs.update({'x_%s'%i:emb[:,i]})
pd.DataFrame(output_embs).to_csv("embeddings/ged_distance_semi/split2/ss_1ep_512_cosine_train_split2.csv")

# %%
val_set = pd.read_csv("data/graph_additional/pairs/splits/split2/val_set_1.csv",index_col=0)

# %%
test_set = pd.read_csv("data/graph_additional/pairs/splits/split2/test_set.csv",index_col=0)

# %%
test_set
# Out:
#                                                rdkit.x  \
# 1    CC12CCC3C(CCC4(O)CC(O)CCC34C=O)C1(O)CCC2C1=CC(...
# 2    CC12CCC3C(CCC4(O)CC(O)CCC34C=O)C1(O)CCC2C1=CC(...
# 3    CC12CCC3C(CCC4(O)CC(O)CCC34C=O)C1(O)CCC2C1=CC(...
# 4    CC12CCC3C(CCC4(O)CC(O)CCC34C=O)C1(O)CCC2C1=CC(...
# 5    CC12CCC3C(CCC4(O)CC(O)CCC34C=O)C1(O)CCC2C1=CC(...
# 6    CC12CCC3C(CCC4(O)CC(O)CCC34C=O)C1(O)CCC2C1=CC(...
# 7    CC12CCC3C(CCC4(O)CC(O)CCC34C=O)C1(O)CCC2C1=CC(...
# 8    CC12CCC3C(CCC4(O)CC(O)CCC34C=O)C1(O)CCC2C1=CC(...
# 9    CC12CCC3C(CCC4(O)CC(O)CCC34C=O)C1(O)CCC2C1=CC(...
# 10   CC12CCC3C(CCC4(O)CC(O)CCC34C=O)C1(O)CCC2C1=CC(...
# 11             O=C1N=C(NCc2cccs2)S/C1=C\c1ccc2ncccc2c1
# 12             O=C1N=C(NCc2cccs2)S/C1=C\c1ccc2ncccc2c1
# 13             O=C1N=C(NCc2cccs2)S/C1=C\c1ccc2ncccc2c1
# 14             O=C1N=C(NCc2cccs2)S/C1=C\c1ccc2ncccc2c1
# 15             O=C1N=C(NCc2cccs2)S/C1=C\c1ccc2ncccc2c1
# 16             O=C1N=C(NCc2cccs2)S/C1=C\c1ccc2ncccc2c1
# 17             O=C1N=C(NCc2cccs2)S/C1=C\c1ccc2ncccc2c1
# 18             O=C1N=C(NCc2cccs2)S/C1=C\c1ccc2ncccc2c1
# 19             O=C1N=C(NCc2cccs2)S/C1=C\c1ccc2ncccc2c1
# 20             O=C1N=C(NCc2cccs2)S/C1=C\c1ccc2ncccc2c1
# 21             O=C1N=C(NCc2cccs2)S/C1=C\c1ccc2ncccc2c1
# 22             O=C1N=C(NCc2cccs2)S/C1=C\c1ccc2ncccc2c1
# 23             O=C1N=C(NCc2cccs2)S/C1=C\c1ccc2ncccc2c1
# 24             O=C1N=C(NCc2cccs2)S/C1=C\c1ccc2ncccc2c1
# 25             O=C1N=C(NCc2cccs2)S/C1=C\c1ccc2ncccc2c1
# 26             O=C1N=C(NCc2cccs2)S/C1=C\c1ccc2ncccc2c1
# 27             O=C1N=C(NCc2cccs2)S/C1=C\c1ccc2ncccc2c1
# 28             O=C1N=C(NCc2cccs2)S/C1=C\c1ccc2ncccc2c1
# 29             O=C1N=C(NCc2cccs2)S/C1=C\c1ccc2ncccc2c1
# 30             O=C1N=C(NCc2cccs2)S/C1=C\c1ccc2ncccc2c1
# ..                                                 ...
# 798  Cc1ccc(NC(=O)c2cccc(C(C)(C)C#N)c2)cc1Nc1ccc2nc...
# 799  Cc1ccc(NC(=O)c2cccc(C(C)(C)C#N)c2)cc1Nc1ccc2nc...
# 800  Cc1ccc(NC(=O)c2cccc(C(C)(C)C#N)c2)cc1Nc1ccc2nc...
# 801  Cc1ccc(NC(=O)c2cccc(C(C)(C)C#N)c2)cc1Nc1ccc2nc...
# 802  Cc1ccc(NC(=O)c2cccc(C(C)(C)C#N)c2)cc1Nc1ccc2nc...
# 803  Cc1ccc(NC(=O)c2cccc(C(C)(C)C#N)c2)cc1Nc1ccc2nc...
# 804  Cc1ccc(NC(=O)c2cccc(C(C)(C)C#N)c2)cc1Nc1ccc2nc...
# 805  Cc1ccc(NC(=O)c2cccc(C(C)(C)C#N)c2)cc1Nc1ccc2nc...
# 806  Cc1ccc(NC(=O)c2cccc(C(C)(C)C#N)c2)cc1Nc1ccc2nc...
# 807  Cc1ccc(NC(=O)c2cccc(C(C)(C)C#N)c2)cc1Nc1ccc2nc...
# 808  Cc1ccc(NC(=O)c2cccc(C(C)(C)C#N)c2)cc1Nc1ccc2nc...
# 809  Cc1ccc(NC(=O)c2cccc(C(C)(C)C#N)c2)cc1Nc1ccc2nc...
# 810  Cc1ccc(NC(=O)c2cccc(C(C)(C)C#N)c2)cc1Nc1ccc2nc...
# 811  Cc1ccc(NC(=O)c2cccc(C(C)(C)C#N)c2)cc1Nc1ccc2nc...
# 812  Cc1ccc(NC(=O)c2cccc(C(C)(C)C#N)c2)cc1Nc1ccc2nc...
# 813  Cc1ccc(NC(=O)c2cccc(C(C)(C)C#N)c2)cc1Nc1ccc2nc...
# 814  Cc1ccc(NC(=O)c2cccc(C(C)(C)C#N)c2)cc1Nc1ccc2nc...
# 815  Cc1ccc(NC(=O)c2cccc(C(C)(C)C#N)c2)cc1Nc1ccc2nc...
# 816  Cc1ccc(NC(=O)c2cccc(C(C)(C)C#N)c2)cc1Nc1ccc2nc...
# 817        CC1=C(/C=C/C(C)=C/C=C/C(C)=C\CO)C(C)(C)CCC1
# 818        CC1=C(/C=C/C(C)=C/C=C/C(C)=C\CO)C(C)(C)CCC1
# 819        CC1=C(/C=C/C(C)=C/C=C/C(C)=C\CO)C(C)(C)CCC1
# 820        CC1=C(/C=C/C(C)=C/C=C/C(C)=C\CO)C(C)(C)CCC1
# 821        CC1=C(/C=C/C(C)=C/C=C/C(C)=C\CO)C(C)(C)CCC1
# 822        CC1=C(/C=C/C(C)=C/C=C/C(C)=C\CO)C(C)(C)CCC1
# 823        CC1=C(/C=C/C(C)=C/C=C/C(C)=C\CO)C(C)(C)CCC1
# 824        CC1=C(/C=C/C(C)=C/C=C/C(C)=C\CO)C(C)(C)CCC1
# 825        CC1=C(/C=C/C(C)=C/C=C/C(C)=C\CO)C(C)(C)CCC1
# 826        CC1=C(/C=C/C(C)=C/C=C/C(C)=C\CO)C(C)(C)CCC1
# 827        CC1=C(/C=C/C(C)=C/C=C/C(C)=C\CO)C(C)(C)CCC1
#
#                                             sig_id  \
# 1        ERG011_VCAP_24H_BRD-A84066268-001-10-3_10
# 2        ERG011_VCAP_24H_BRD-A84066268-001-10-3_10
# 3        ERG011_VCAP_24H_BRD-A84066268-001-10-3_10
# 4        ERG011_VCAP_24H_BRD-A84066268-001-10-3_10
# 5        ERG011_VCAP_24H_BRD-A84066268-001-10-3_10
# 6        ERG011_VCAP_24H_BRD-A84066268-001-10-3_10
# 7        ERG011_VCAP_24H_BRD-A84066268-001-10-3_10
# 8        ERG011_VCAP_24H_BRD-A84066268-001-10-3_10
# 9        ERG011_VCAP_24H_BRD-A84066268-001-10-3_10
# 10       ERG011_VCAP_24H_BRD-A84066268-001-10-3_10
# 11        CPC020_HA1E_6H_BRD-K78373679-001-01-1_10
# 12        CPC020_HA1E_6H_BRD-K78373679-001-01-1_10
# 13        CPC020_HA1E_6H_BRD-K78373679-001-01-1_10
# 14        CPC020_HA1E_6H_BRD-K78373679-001-01-1_10
# 15        CPC020_HA1E_6H_BRD-K78373679-001-01-1_10
# 16        CPC020_HA1E_6H_BRD-K78373679-001-01-1_10
# 17        CPC020_HA1E_6H_BRD-K78373679-001-01-1_10
# 18        CPC020_HA1E_6H_BRD-K78373679-001-01-1_10
# 19        CPC020_HA1E_6H_BRD-K78373679-001-01-1_10
# 20        CPC020_HA1E_6H_BRD-K78373679-001-01-1_10
# 21        CPC020_MCF7_6H_BRD-K78373679-001-01-1_10
# 22         CPC020_PC3_6H_BRD-K78373679-001-01-1_10
# 23         CPC020_PC3_6H_BRD-K78373679-001-01-1_10
# 24         CPC020_PC3_6H_BRD-K78373679-001-01-1_10
# 25         CPC020_PC3_6H_BRD-K78373679-001-01-1_10
# 26         CPC020_PC3_6H_BRD-K78373679-001-01-1_10
# 27         CPC020_PC3_6H_BRD-K78373679-001-01-1_10
# 28         CPC020_PC3_6H_BRD-K78373679-001-01-1_10
# 29         CPC020_PC3_6H_BRD-K78373679-001-01-1_10
# 30         CPC020_PC3_6H_BRD-K78373679-001-01-1_10
# ..                                             ...
# 798    LJP001_MCF10A_24H_BRD-K05804044-001-02-9_10
# 799    LJP001_MCF10A_24H_BRD-K05804044-001-02-9_10
# 800    LJP001_MCF10A_24H_BRD-K05804044-001-02-9_10
# 801    LJP001_MCF10A_24H_BRD-K05804044-001-02-9_10
# 802    LJP001_MCF10A_24H_BRD-K05804044-001-02-9_10
# 803    LJP001_MCF10A_24H_BRD-K05804044-001-02-9_10
# 804    LJP001_MCF10A_24H_BRD-K05804044-001-02-9_10
# 805    LJP001_MCF10A_24H_BRD-K05804044-001-02-9_10
# 806    LJP001_MCF10A_24H_BRD-K05804044-001-02-9_10
# 807  LJP001_MDAMB231_24H_BRD-K05804044-001-02-9_10
# 808  LJP001_MDAMB231_24H_BRD-K05804044-001-02-9_10
# 809  LJP001_MDAMB231_24H_BRD-K05804044-001-02-9_10
# 810  LJP001_MDAMB231_24H_BRD-K05804044-001-02-9_10
# 811  LJP001_MDAMB231_24H_BRD-K05804044-001-02-9_10
# 812  LJP001_MDAMB231_24H_BRD-K05804044-001-02-9_10
# 813  LJP001_MDAMB231_24H_BRD-K05804044-001-02-9_10
# 814  LJP001_MDAMB231_24H_BRD-K05804044-001-02-9_10
# 815  LJP001_MDAMB231_24H_BRD-K05804044-001-02-9_10
# 816  LJP001_MDAMB231_24H_BRD-K05804044-001-02-9_10
# 817       CPC014_A375_6H_BRD-K13927029-001-01-9_10
# 818       CPC014_MCF7_6H_BRD-K13927029-001-01-9_10
# 819       CPC014_MCF7_6H_BRD-K13927029-001-01-9_10
# 820       CPC014_MCF7_6H_BRD-K13927029-001-01-9_10
# 821       CPC014_MCF7_6H_BRD-K13927029-001-01-9_10
# 822       CPC014_MCF7_6H_BRD-K13927029-001-01-9_10
# 823       CPC014_MCF7_6H_BRD-K13927029-001-01-9_10
# 824       CPC014_MCF7_6H_BRD-K13927029-001-01-9_10
# 825       CPC014_MCF7_6H_BRD-K13927029-001-01-9_10
# 826       CPC014_MCF7_6H_BRD-K13927029-001-01-9_10
# 827       CPC014_MCF7_6H_BRD-K13927029-001-01-9_10
#
#                                                 graphs   pert_iname.x  \
# 1    graphs_combined/ERG011_VCAP_24H_BRD-A84066268-...  BRD-A84066268
# 2    graphs_combined/ERG011_VCAP_24H_BRD-A84066268-...  BRD-A84066268
# 3    graphs_combined/ERG011_VCAP_24H_BRD-A84066268-...  BRD-A84066268
# 4    graphs_combined/ERG011_VCAP_24H_BRD-A84066268-...  BRD-A84066268
# 5    graphs_combined/ERG011_VCAP_24H_BRD-A84066268-...  BRD-A84066268
# 6    graphs_combined/ERG011_VCAP_24H_BRD-A84066268-...  BRD-A84066268
# 7    graphs_combined/ERG011_VCAP_24H_BRD-A84066268-...  BRD-A84066268
# 8    graphs_combined/ERG011_VCAP_24H_BRD-A84066268-...  BRD-A84066268
# 9    graphs_combined/ERG011_VCAP_24H_BRD-A84066268-...  BRD-A84066268
# 10   graphs_combined/ERG011_VCAP_24H_BRD-A84066268-...  BRD-A84066268
# 11   graphs_combined/CPC020_HA1E_6H_BRD-K78373679-0...        Ro-3306
# 12   graphs_combined/CPC020_HA1E_6H_BRD-K78373679-0...        Ro-3306
# 13   graphs_combined/CPC020_HA1E_6H_BRD-K78373679-0...        Ro-3306
# 14   graphs_combined/CPC020_HA1E_6H_BRD-K78373679-0...        Ro-3306
# 15   graphs_combined/CPC020_HA1E_6H_BRD-K78373679-0...        Ro-3306
# 16   graphs_combined/CPC020_HA1E_6H_BRD-K78373679-0...        Ro-3306
# 17   graphs_combined/CPC020_HA1E_6H_BRD-K78373679-0...        Ro-3306
# 18   graphs_combined/CPC020_HA1E_6H_BRD-K78373679-0...        Ro-3306
# 19   graphs_combined/CPC020_HA1E_6H_BRD-K78373679-0...        Ro-3306
# 20   graphs_combined/CPC020_HA1E_6H_BRD-K78373679-0...        Ro-3306
# 21   graphs_combined/CPC020_MCF7_6H_BRD-K78373679-0...        Ro-3306
# 22   graphs_combined/CPC020_PC3_6H_BRD-K78373679-00...        Ro-3306
# 23   graphs_combined/CPC020_PC3_6H_BRD-K78373679-00...        Ro-3306
# 24   graphs_combined/CPC020_PC3_6H_BRD-K78373679-00...        Ro-3306
# 25   graphs_combined/CPC020_PC3_6H_BRD-K78373679-00...        Ro-3306
# 26   graphs_combined/CPC020_PC3_6H_BRD-K78373679-00...        Ro-3306
# 27   graphs_combined/CPC020_PC3_6H_BRD-K78373679-00...        Ro-3306
# 28   graphs_combined/CPC020_PC3_6H_BRD-K78373679-00...        Ro-3306
# 29   graphs_combined/CPC020_PC3_6H_BRD-K78373679-00...        Ro-3306
# 30   graphs_combined/CPC020_PC3_6H_BRD-K78373679-00...        Ro-3306
# ..                                                 ...            ...
# 798  graphs_combined/LJP001_MCF10A_24H_BRD-K0580404...         AZ-628
# 799  graphs_combined/LJP001_MCF10A_24H_BRD-K0580404...         AZ-628
# 800  graphs_combined/LJP001_MCF10A_24H_BRD-K0580404...         AZ-628
# 801  graphs_combined/LJP001_MCF10A_24H_BRD-K0580404...         AZ-628
# 802  graphs_combined/LJP001_MCF10A_24H_BRD-K0580404...         AZ-628
# 803  graphs_combined/LJP001_MCF10A_24H_BRD-K0580404...         AZ-628
# 804  graphs_combined/LJP001_MCF10A_24H_BRD-K0580404...         AZ-628
# 805  graphs_combined/LJP001_MCF10A_24H_BRD-K0580404...         AZ-628
# 806  graphs_combined/LJP001_MCF10A_24H_BRD-K0580404...         AZ-628
# 807  graphs_combined/LJP001_MDAMB231_24H_BRD-K05804...         AZ-628
# 808  graphs_combined/LJP001_MDAMB231_24H_BRD-K05804...         AZ-628
# 809  graphs_combined/LJP001_MDAMB231_24H_BRD-K05804...         AZ-628
# 810  graphs_combined/LJP001_MDAMB231_24H_BRD-K05804...         AZ-628
# 811  graphs_combined/LJP001_MDAMB231_24H_BRD-K05804...         AZ-628
# 812  graphs_combined/LJP001_MDAMB231_24H_BRD-K05804...         AZ-628
# 813  graphs_combined/LJP001_MDAMB231_24H_BRD-K05804...         AZ-628
# 814  graphs_combined/LJP001_MDAMB231_24H_BRD-K05804...         AZ-628
# 815  graphs_combined/LJP001_MDAMB231_24H_BRD-K05804...         AZ-628
# 816  graphs_combined/LJP001_MDAMB231_24H_BRD-K05804...         AZ-628
# 817  graphs_combined/CPC014_A375_6H_BRD-K13927029-0...        retinol
# 818  graphs_combined/CPC014_MCF7_6H_BRD-K13927029-0...        retinol
# 819  graphs_combined/CPC014_MCF7_6H_BRD-K13927029-0...        retinol
# 820  graphs_combined/CPC014_MCF7_6H_BRD-K13927029-0...        retinol
# 821  graphs_combined/CPC014_MCF7_6H_BRD-K13927029-0...        retinol
# 822  graphs_combined/CPC014_MCF7_6H_BRD-K13927029-0...        retinol
# 823  graphs_combined/CPC014_MCF7_6H_BRD-K13927029-0...        retinol
# 824  graphs_combined/CPC014_MCF7_6H_BRD-K13927029-0...        retinol
# 825  graphs_combined/CPC014_MCF7_6H_BRD-K13927029-0...        retinol
# 826  graphs_combined/CPC014_MCF7_6H_BRD-K13927029-0...        retinol
# 827  graphs_combined/CPC014_MCF7_6H_BRD-K13927029-0...        retinol
#
#     cell_id.x                                                emb  \
# 1        VCAP    ERG011_VCAP_24H_BRD-A84066268-001-10-3_10_emb_1
# 2        VCAP   ERG011_VCAP_24H_BRD-A84066268-001-10-3_10_emb_10
# 3        VCAP  ERG011_VCAP_24H_BRD-A84066268-001-10-3_10_emb_100
# 4        VCAP   ERG011_VCAP_24H_BRD-A84066268-001-10-3_10_emb_11
# 5        VCAP   ERG011_VCAP_24H_BRD-A84066268-001-10-3_10_emb_12
# 6        VCAP   ERG011_VCAP_24H_BRD-A84066268-001-10-3_10_emb_13
# 7        VCAP   ERG011_VCAP_24H_BRD-A84066268-001-10-3_10_emb_14
# 8        VCAP   ERG011_VCAP_24H_BRD-A84066268-001-10-3_10_emb_15
# 9        VCAP   ERG011_VCAP_24H_BRD-A84066268-001-10-3_10_emb_16
# 10       VCAP   ERG011_VCAP_24H_BRD-A84066268-001-10-3_10_emb_17
# 11       HA1E     CPC020_HA1E_6H_BRD-K78373679-001-01-1_10_emb_1
# 12       HA1E    CPC020_HA1E_6H_BRD-K78373679-001-01-1_10_emb_10
# 13       HA1E   CPC020_HA1E_6H_BRD-K78373679-001-01-1_10_emb_100
# 14       HA1E    CPC020_HA1E_6H_BRD-K78373679-001-01-1_10_emb_11
# 15       HA1E    CPC020_HA1E_6H_BRD-K78373679-001-01-1_10_emb_12
# 16       HA1E    CPC020_HA1E_6H_BRD-K78373679-001-01-1_10_emb_13
# 17       HA1E    CPC020_HA1E_6H_BRD-K78373679-001-01-1_10_emb_14
# 18       HA1E    CPC020_HA1E_6H_BRD-K78373679-001-01-1_10_emb_15
# 19       HA1E    CPC020_HA1E_6H_BRD-K78373679-001-01-1_10_emb_16
# 20       HA1E    CPC020_HA1E_6H_BRD-K78373679-001-01-1_10_emb_17
# 21       MCF7     CPC020_MCF7_6H_BRD-K78373679-001-01-1_10_emb_1
# 22        PC3      CPC020_PC3_6H_BRD-K78373679-001-01-1_10_emb_1
# 23        PC3     CPC020_PC3_6H_BRD-K78373679-001-01-1_10_emb_10
# 24        PC3     CPC020_PC3_6H_BRD-K78373679-001-01-1_10_emb_11
# 25        PC3     CPC020_PC3_6H_BRD-K78373679-001-01-1_10_emb_12
# 26        PC3     CPC020_PC3_6H_BRD-K78373679-001-01-1_10_emb_13
# 27        PC3     CPC020_PC3_6H_BRD-K78373679-001-01-1_10_emb_14
# 28        PC3      CPC020_PC3_6H_BRD-K78373679-001-01-1_10_emb_2
# 29        PC3      CPC020_PC3_6H_BRD-K78373679-001-01-1_10_emb_3
# 30        PC3      CPC020_PC3_6H_BRD-K78373679-001-01-1_10_emb_4
# ..        ...                                                ...
# 798    MCF10A  LJP001_MCF10A_24H_BRD-K05804044-001-02-9_10_em...
# 799    MCF10A  LJP001_MCF10A_24H_BRD-K05804044-001-02-9_10_em...
# 800    MCF10A  LJP001_MCF10A_24H_BRD-K05804044-001-02-9_10_em...
# 801    MCF10A  LJP001_MCF10A_24H_BRD-K05804044-001-02-9_10_em...
# 802    MCF10A  LJP001_MCF10A_24H_BRD-K05804044-001-02-9_10_em...
# 803    MCF10A  LJP001_MCF10A_24H_BRD-K05804044-001-02-9_10_em...
# 804    MCF10A  LJP001_MCF10A_24H_BRD-K05804044-001-02-9_10_em...
# 805    MCF10A  LJP001_MCF10A_24H_BRD-K05804044-001-02-9_10_em...
# 806    MCF10A  LJP001_MCF10A_24H_BRD-K05804044-001-02-9_10_em...
# 807  MDAMB231  LJP001_MDAMB231_24H_BRD-K05804044-001-02-9_10_...
# 808  MDAMB231  LJP001_MDAMB231_24H_BRD-K05804044-001-02-9_10_...
# 809  MDAMB231  LJP001_MDAMB231_24H_BRD-K05804044-001-02-9_10_...
# 810  MDAMB231  LJP001_MDAMB231_24H_BRD-K05804044-001-02-9_10_...
# 811  MDAMB231  LJP001_MDAMB231_24H_BRD-K05804044-001-02-9_10_...
# 812  MDAMB231  LJP001_MDAMB231_24H_BRD-K05804044-001-02-9_10_...
# 813  MDAMB231  LJP001_MDAMB231_24H_BRD-K05804044-001-02-9_10_...
# 814  MDAMB231  LJP001_MDAMB231_24H_BRD-K05804044-001-02-9_10_...
# 815  MDAMB231  LJP001_MDAMB231_24H_BRD-K05804044-001-02-9_10_...
# 816  MDAMB231  LJP001_MDAMB231_24H_BRD-K05804044-001-02-9_10_...
# 817      A375     CPC014_A375_6H_BRD-K13927029-001-01-9_10_emb_1
# 818      MCF7     CPC014_MCF7_6H_BRD-K13927029-001-01-9_10_emb_1
# 819      MCF7    CPC014_MCF7_6H_BRD-K13927029-001-01-9_10_emb_10
# 820      MCF7   CPC014_MCF7_6H_BRD-K13927029-001-01-9_10_emb_100
# 821      MCF7    CPC014_MCF7_6H_BRD-K13927029-001-01-9_10_emb_11
# 822      MCF7    CPC014_MCF7_6H_BRD-K13927029-001-01-9_10_emb_12
# 823      MCF7    CPC014_MCF7_6H_BRD-K13927029-001-01-9_10_emb_13
# 824      MCF7    CPC014_MCF7_6H_BRD-K13927029-001-01-9_10_emb_14
# 825      MCF7    CPC014_MCF7_6H_BRD-K13927029-001-01-9_10_emb_15
# 826      MCF7    CPC014_MCF7_6H_BRD-K13927029-001-01-9_10_emb_16
# 827      MCF7    CPC014_MCF7_6H_BRD-K13927029-001-01-9_10_emb_17
#
#                       moa_v1
# 1    atp_synthesis_inhibitor
# 2    atp_synthesis_inhibitor
# 3    atp_synthesis_inhibitor
# 4    atp_synthesis_inhibitor
# 5    atp_synthesis_inhibitor
# 6    atp_synthesis_inhibitor
# 7    atp_synthesis_inhibitor
# 8    atp_synthesis_inhibitor
# 9    atp_synthesis_inhibitor
# 10   atp_synthesis_inhibitor
# 11             cdk_inhibitor
# 12             cdk_inhibitor
# 13             cdk_inhibitor
# 14             cdk_inhibitor
# 15             cdk_inhibitor
# 16             cdk_inhibitor
# 17             cdk_inhibitor
# 18             cdk_inhibitor
# 19             cdk_inhibitor
# 20             cdk_inhibitor
# 21             cdk_inhibitor
# 22             cdk_inhibitor
# 23             cdk_inhibitor
# 24             cdk_inhibitor
# 25             cdk_inhibitor
# 26             cdk_inhibitor
# 27             cdk_inhibitor
# 28             cdk_inhibitor
# 29             cdk_inhibitor
# 30             cdk_inhibitor
# ..                       ...
# 798            raf_inhibitor
# 799            raf_inhibitor
# 800            raf_inhibitor
# 801            raf_inhibitor
# 802            raf_inhibitor
# 803            raf_inhibitor
# 804            raf_inhibitor
# 805            raf_inhibitor
# 806            raf_inhibitor
# 807            raf_inhibitor
# 808            raf_inhibitor
# 809            raf_inhibitor
# 810            raf_inhibitor
# 811            raf_inhibitor
# 812            raf_inhibitor
# 813            raf_inhibitor
# 814            raf_inhibitor
# 815            raf_inhibitor
# 816            raf_inhibitor
# 817  retinoid_agonist_ligand
# 818  retinoid_agonist_ligand
# 819  retinoid_agonist_ligand
# 820  retinoid_agonist_ligand
# 821  retinoid_agonist_ligand
# 822  retinoid_agonist_ligand
# 823  retinoid_agonist_ligand
# 824  retinoid_agonist_ligand
# 825  retinoid_agonist_ligand
# 826  retinoid_agonist_ligand
# 827  retinoid_agonist_ligand
#
# [827 rows x 7 columns]

# %%
#Later to embeed unseen
nets_paths=list(test_set['graphs'])
graph_df=[pd.read_csv(x,index_col=0).reset_index(drop=True) for x in nets_paths]
nets=[df_to_nx(x) for x in graph_df]
graphs_nx=tensorize_signalnet(nets,prot_dict,100,21,shapes_dict)
emb=encoder_nikos.predict([graphs_nx[0],graphs_nx[1],graphs_nx[2]],batch_size=512)
emb_id=[]
for f in nets_paths:
    emb_id.append(f.strip(".csv").split("/")[-2] + "_emb_" + str(f.strip(".csv").split("_")[-1]))
output_embs={}
output_embs.update({'emb':emb_id})
for i in range(512):
    output_embs.update({'x_%s'%i:emb[:,i]})
pd.DataFrame(output_embs).to_csv("embeddings/ged_distance_semi/split2/ged_ss_1ep_test_set_split2.csv")

# %%
#Later to embeed unseen
nets_paths=list(val_set['graphs'])
graph_df=[pd.read_csv(x,index_col=0).reset_index(drop=True) for x in nets_paths]
nets=[df_to_nx(x) for x in graph_df]
graphs_nx=tensorize_signalnet(nets,prot_dict,100,21,shapes_dict)
emb=encoder_nikos.predict([graphs_nx[0],graphs_nx[1],graphs_nx[2]],batch_size=512)
emb_id=[]
for f in nets_paths:
    emb_id.append(f.strip(".csv").split("/")[-2] + "_emb_" + str(f.strip(".csv").split("_")[-1]))
output_embs={}
output_embs.update({'emb':emb_id})
for i in range(512):
    output_embs.update({'x_%s'%i:emb[:,i]})
pd.DataFrame(output_embs).to_csv("embeddings/ged_distance_semi/split2/ged_ss_3ep_val_set_1_split2.csv")

# %% [markdown]
# # Train more

# %%
siamese_net.load_weights("Ugraphemp/models/siamese_model512_2.h5")

# %%
# Train with fitgen
rlr = ReduceLROnPlateau(monitor='loss', factor=0.5,patience=2, min_lr=0.00001, verbose=1, min_delta=1e-5)
term=keras.callbacks.TerminateOnNaN()
bs=512
NUM_EPOCHS = 2
df_pairs = df_pairs.sample(frac=1).reset_index(drop=True)
#Set total number of training samples and tests samples
NUM_TRAIN = len(df_pairs)
trainGen=train_generator(bs,df_pairs,nets_paths,graphs_nx,shapes_dict,prot_dict,max_prots,max_degree)
history = siamese_net.fit_generator(trainGen,
                                    steps_per_epoch= ceil(NUM_TRAIN/bs),
                                    epochs=NUM_EPOCHS,
                                    verbose = 1,
                                    shuffle = True,
                                    callbacks= [term, rlr])
# Out:
# Epoch 1/2
# 9209/9209 [==============================] - 6541s 710ms/step - loss: -2.5374 - mean_squared_error: 0.0058 - get_cindex: 0.8620 - r_square: 0.6774 - pearson_r: 0.8328
# Epoch 2/2
# 9209/9209 [==============================] - 6515s 707ms/step - loss: -2.6491 - mean_squared_error: 0.0050 - get_cindex: 0.8777 - r_square: 0.7207 - pearson_r: 0.8593

# %%
siamese_net.save_weights("Ugraphemp/models/siamese_model512_4.h5")
encoder_nikos.save_weights("Ugraphemp/models/encoder_model512_4.h5")

# %%
emb=encoder_nikos.predict([graphs_nx[0],graphs_nx[1],graphs_nx[2]],batch_size=512)

# %%
emb_id=[]
for f in nets_paths:
    emb_id.append(f.strip(".csv").split("/")[-2] + "_emb_" + str(f.strip(".csv").split("_")[-1]))
output_embs={}
output_embs.update({'emb':emb_id})
for i in range(128):
    output_embs.update({'x_%s'%i:emb[:,i]})
pd.DataFrame(output_embs).to_csv("Ugraphemp/embeddings/ged_embs512_seen_4ep.csv")

# %%
#Later to embeed unseen
nets_paths=list(samples_all['path_list'])
graph_df=[pd.read_csv(graphs_location+x,index_col=0).reset_index(drop=True) for x in nets_paths]
nets=[df_to_nx(x) for x in graph_df]
graphs_nx=tensorize_signalnet(nets,prot_dict,100,21,shapes_dict)
emb=encoder_nikos.predict([graphs_nx[0],graphs_nx[1],graphs_nx[2]],batch_size=512)
emb_id=[]
for f in nets_paths:
    emb_id.append(f.strip(".csv").split("/")[-2] + "_emb_" + str(f.strip(".csv").split("_")[-1]))
output_embs={}
output_embs.update({'emb':emb_id})
for i in range(128):
    output_embs.update({'x_%s'%i:emb[:,i]})
pd.DataFrame(output_embs).to_csv("Ugraphemp/embeddings/ged_embs512_samples_all_4ep.csv")

# %% [markdown]
# # Example for pravious projects

# %%
for i in [4]:
    
    #Load data
    df = pd.read_csv("a375/" + "fold_%s/train_%s.csv" %(i+1,i+1),index_col=0).reset_index(drop=True)
    smiles=list(set(list(df['rdkit.x'])+list(df['rdkit.y'])))
    X_atoms, X_bonds, X_edges = tensorise_smiles(smiles, max_degree, max_atoms)
    df_cold = pd.read_csv("a375/" + "fold_%s/val_%s.csv" %(i+1,i+1),index_col=0).reset_index(drop=True)
    smiles_cold = list(set(list(df_cold['rdkit.x'])+list(df_cold['rdkit.y'])))
    X_atoms_cold, X_bonds_cold, X_edges_cold = tensorise_smiles(smiles_cold, max_degree=5, max_atoms = 60)
    Y_cold = df_cold.value/2
    
    n=8
    cold_preds_mus = []
    cold_preds_sigmas = []
    while n<10:
        
        # Initialize encoder
        encoder_nikos = enc_nikos(p, 0.001, 128, 256)
    
        # Initialize model
        prots0_1 = Input(name='atom_inputs_1', shape=(max_prots, num_prot_features),dtype = 'float32')
        edgattr_1 = Input(name='edgattr_inputs_1', shape=(max_prots, max_degree, num_edge_features),dtype = 'float32')
        edges_1 = Input(name='edge_inputs_1', shape=(max_prots, max_degree), dtype='int32')

        prots0_2 = Input(name='atom_inputs_2', shape=(max_prots, num_prot_features),dtype = 'float32')
        edgattr_2 = Input(name='edgattr_inputs_2', shape=(max_prots, max_degree, num_edge_features),dtype = 'float32')
        edges_2 =Input(name='edge_inputs_2', shape=(max_prots, max_degree), dtype='int32')

        encoded_1 = encoder_nikos([prots0_1,edgattr_1,edges_1])
        #encoded_1 =keras.layers.Flatten()(encoded_1)
        encoded_2 = encoder_nikos([prots0_2,edgattr_2,edges_2])
        #encoded_2 = keras.layers.Flatten()(encoded_2)

        #K dot
        #product_layer=keras.layers.Lambda(lambda tensors:tf.linalg.trace(K.batch_dot(tensors[0],tensors[1],axes=2)))
        #product_layer=keras.layers.Lambda(lambda tensors:tf.reduce_sum(K.batch_dot(tensors[0],tensors[1],axes=2),[1, 2]))
        product_layer=keras.layers.Lambda(lambda tensors:K.batch_dot(tensors[0],tensors[1],axes=2))
        product=product_layer([encoded_1, encoded_2])

        c1=keras.layers.Conv1D(128, 32, activation=None, use_bias=False, kernel_initializer='glorot_uniform')(product)
        c1= BatchNormalization(momentum=0.6)(c1)
        c1= Activation('relu')(c1)
        c1=keras.layers.Dropout(0.25)(c1)
        c1=keras.layers.Flatten()(c1)


        mu, sigma = GaussianLayer(1, name='main_output')(c1)


        siamese_net = Model(inputs=[prots0_1,edgattr_1,edges_1,prots0_2,edgattr_2,edges_2],outputs=mu)
        print(siamese_net.summary())
        adam = keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-8, decay=0.0, amsgrad=False)
        siamese_net.compile(optimizer= adam,loss= custom_loss(sigma),metrics=['mse', get_cindex, r_square, pearson_r])

        # Train with fitgen
        rlr = ReduceLROnPlateau(monitor='loss', factor=0.5,patience=2, min_lr=0.00001, verbose=1, min_delta=1e-5)
        term=keras.callbacks.TerminateOnNaN()
        bs=128
        NUM_EPOCHS = 20
        df = df.sample(frac=1).reset_index(drop=True)
        #Set total number of training samples and tests samples
        NUM_TRAIN = len(df)
        trainGen=train_generator(bs,df,smiles,X_atoms, X_bonds, X_edges)
        history = siamese_net.fit_generator(trainGen,
                                            steps_per_epoch= ceil(NUM_TRAIN/bs),
                                            epochs=NUM_EPOCHS,
                                            verbose = 1,
                                            shuffle = True,
                                            callbacks= [term, rlr])
        
        if history.history["r_square"][len(history.history["r_square"])-1] < 0.7:
            history = siamese_net.fit_generator(trainGen,
                                             steps_per_epoch= ceil(NUM_TRAIN/bs),
                                             epochs = 10,
                                             verbose = 1,
                                             shuffle = True,
                                             callbacks= [term, rlr])
        if history.history["r_square"][len(history.history["r_square"])-1] >= 0.7:
            siamese_net.save_weights("a375/results/" + "fold_%s/models/"%(i+1) + "model_%s.h5"%n)
            gaussian = keras.Model(siamese_net.inputs, siamese_net.get_layer('main_output').output)
            pr_steps=ceil(len(df_cold)/2048)
            PredGen=preds_generator(2048,df_cold,smiles_cold,X_atoms_cold, X_bonds_cold, X_edges_cold,gaussian)
            y_pred1=[]
            y_pred2=[]
            for g in range(pr_steps):
                cold_pred=list(next(PredGen))
                y_pred1=y_pred1+list(cold_pred[0])
                y_pred2=y_pred2+list(cold_pred[1])
            y_pred1=np.array(y_pred1)
            y_pred2=np.array(y_pred2)
            if (len(y_pred1[np.where(y_pred1 <= 0.2)])>0):
                get = model_evaluate(y_pred1,Y_cold,0.2,df_cold)
                get.to_csv("a375/results/" + "fold_%s/performance/"%(i+1) + "model_%s.csv"%n)
            cold_preds_mus.append(y_pred1)
            np.save("a375/results/"+ "fold_%s/cold/mu/"%(i+1) + "cold_mu_%s.npy"%n, y_pred1)
            cold_preds_sigmas.append(y_pred2)
            np.save("a375/results/" + "fold_%s/cold/sigma/"%(i+1) + "cold_sigma_%s.npy"%n, y_pred2)
            n=n+1
    
    mu_star=np.mean(cold_preds_mus,axis=0)
    sigma_star = np.sqrt(np.mean(cold_preds_sigmas + np.square(cold_preds_mus), axis = 0) - np.square(mu_star))
    cv_star = sigma_star/mu_star
    if (len(mu_star[np.where(mu_star <= 0.2)])>0):
        get_fold = model_evaluate(mu_star,Y_cold,0.2,df_cold)
        get_fold.to_csv("a375/results/" + "fold_%s/ensemble_performance.csv"%(i+1))
    df_cold['mu'] = mu_star
    df_cold['cv'] = cv_star
    df_cold.to_csv("a375/results/" + "fold_%s/ensemble_preds_dataframe.csv"%(i+1))

# %%
cold_preds_mus = []
cold_preds_sigmas = []
for n in range(10):
    cold_preds_mus.append(np.load("a375/results/fold_5/cold/mu/cold_mu_%s.npy"%n))
    cold_preds_sigmas.append(np.load("a375/results/fold_5/cold/sigma/cold_sigma_%s.npy"%n))

mu_star=np.mean(cold_preds_mus,axis=0)
sigma_star = np.sqrt(np.mean(cold_preds_sigmas + np.square(cold_preds_mus), axis = 0) - np.square(mu_star))
cv_star = sigma_star/mu_star
if (len(mu_star[np.where(mu_star <= 0.2)])>0):
    get_fold = model_evaluate(mu_star,Y_cold,0.2,df_cold)
    get_fold.to_csv("a375/results/fold_5/ensemble_performance.csv")
    df_cold['mu'] = mu_star
    df_cold['cv'] = cv_star
    df_cold.to_csv("a375/results/fold_5/ensemble_preds_dataframe.csv")

# %%
get_fold_all={'cor' : [], 'mse_all' : [], 'mse_similars' : [],'precision': [], 'accuracy': [],'positives' : []}

# %%
for i in range(1,6):
    get=pd.read_csv("a375/results/fold_%s/ensemble_performance.csv"%i,index_col=0)
    get_fold_all['cor'].append(get['cor'][0])
    get_fold_all['mse_all'].append(get['mse_all'][0])
    get_fold_all['mse_similars'].append(get['mse_similars'][0])
    get_fold_all['precision'].append(get['precision'][0])
    get_fold_all['accuracy'].append(get['accuracy'][0])
    get_fold_all['positives'].append(get['positives'][0])

# %%
get_fold_all=pd.DataFrame(get_fold_all)

# %%
get_fold_all

# %%
pd.DataFrame({'cor' : get_fold_all['cor'].mean(), 'mse_all' : get_fold_all['mse_all'].mean(), 'mse_similars' : get_fold_all['mse_similars'].mean(),
              'precision': get_fold_all['precision'].mean(), 'accuracy': get_fold_all['accuracy'].mean(),'positives' : ceil(get_fold_all['positives'].mean())}, index=[0]).to_csv("a375/results/cross_ensemble_performance.csv")

# %%
pd.DataFrame({'cor' : get_fold_all['cor'].mean(), 'mse_all' : get_fold_all['mse_all'].mean(), 'mse_similars' : get_fold_all['mse_similars'].mean(),
              'precision': get_fold_all['precision'].mean(), 'accuracy': get_fold_all['accuracy'].mean(),'positives' : ceil(get_fold_all['positives'].mean())}, index=[0])

# %% [markdown]
# # General stuff

# %%
def net2json(df):
    nodes=list(set(list(df['node1']) + list(df['node2'])))
    #read pickle in the folder you are
    #import pickle
    #filep=open('ReSimNet-Dataset.pkl','rb')
    #prot_enc=pickle.load(filep)
    #filep.close()
    if "Perturbation" in nodes:
        nodes.remove("Perturbation")
    #nodes[nodes.index("Perturbation")]=nodes[0]
    #nodes[0]="Perturbation"
    feats={}
    for j,x in enumerate(nodes):
        if (x in list(df['node1'])):
            activity=list(df['activity1'])[list(df['node1']).index(x)]
        else:
            activity=list(df['activity2'])[list(df['node2']).index(x)]
        sign = lambda a: '-' if (int(a)==-1) else '+'
        feats.update({"%s"%j:x+sign(activity)})
    net={}
    net.update({"edges":[]})
    net.update({"features":feats})
    for j in range(1,len(df)):
        if ((df['node1'][j]!="Perturbation") and (df['node2'][j]!="Perturbation")):
            ind1=nodes.index(df['node1'][j])
            ind2=nodes.index(df['node2'][j])
            net["edges"].append([ind1,ind2])
    return(net)

# %%
info=pd.read_csv("file_info.csv",index_col=0)

# %%
#find how to copy file in python
#from shutil import copyfile
import json
path_list=[]
embed_id=[]
prev_sig=[]
counter=0
for (i in range(len(info))):
    if (info['sig_id'][i] not in prev_sig):
        #copyfile(info['files_combined'][i], "drive/My Drive/Computational_projects/deepsnem/graph2vec")
        path_list.append(info['files_combined'][i])
        embed_id.append(info['emb'][i])
        prev_sig.append(info['sig_id'][i])
        counter+=1
    if counter==7788:
        break
for (i,x in enumerate(path_list)):
    df=pd.read_csv(x,index_col=0)
    net=net2json(df)
    with open('carn_data/'+embed_id[i]+'.json', 'w') as fp:
        json.dump(net, fp)

# %%
def getMCS(G_source, G_new):
    matching_graph=nx.Graph()

    for n1,n2,attr in G_new.edges(data=True):
        if G_source.has_edge(n1,n2) :
            if G_source[n1][n2]['weight']==G_new[n1][n2]['weight']:
                matching_graph.add_edge(n1,n2,weight=attr)

    graphs = list(nx.connected_components(matching_graph))

    mcs_length = 0
    mcs_graph = nx.Graph()
    for i, graph in enumerate(graphs):

        if len(graph) > mcs_length:
            mcs_length = len(graph)
            mcs_graph = graph

    return [mcs_length,mcs_graph]
