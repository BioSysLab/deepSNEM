# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '1.12.0'

# %%
import pickle


with open('embeddings/unet/unet_embeddings.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
data[135].shape
# Out:
# (128,)

# %%
data.shape
# Out:
# (69170, 128)

# %%
import pandas as pd

# %%
emb = pd.DataFrame(data)

# %%
emb
# Out:
#                 0             1             2             3             4    \
# 0      4.130515e-09  6.726986e-11  4.087216e-09  2.599546e-07  1.051297e-09
# 1      4.919375e-10  4.747961e-08  3.482896e-09  6.839063e-07  2.047478e-08
# 2      1.726810e-05  1.541937e-03  1.435296e-05  1.760160e-06  3.372693e-08
# 3      9.182958e-09  6.680111e-08  5.460562e-08  1.215627e-06  3.618775e-08
# 4      3.333381e-10  4.824691e-08  3.778855e-08  4.369035e-07  5.935711e-10
# 5      1.099101e-06  3.256449e-02  1.519016e-08  6.440639e-08  1.915432e-08
# 6      1.430207e-04  4.422201e-04  3.330213e-04  5.994480e-06  5.334581e-06
# 7      1.892688e-10  5.790806e-12  3.382464e-10  3.486724e-08  5.199330e-11
# 8      1.952178e-08  2.889538e-08  2.045609e-07  1.931828e-06  1.276282e-07
# 9      5.583100e-10  8.541829e-12  6.020970e-10  1.102531e-07  2.572367e-10
# 10     1.553335e-05  5.059804e-05  7.844345e-05  5.739794e-07  8.599918e-07
# ...

# %%
emb.to_csv("embeddings/unet/embeddings_unet_128.csv")
